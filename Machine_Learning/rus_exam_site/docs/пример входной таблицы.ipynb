# %%
import pandas as pd

path = r'C:\Users\dmi-a\OneDrive\Рабочий стол\DS учеба\Выполненные проекты\Экзамен на знание русского языка\docs\Данные для кейса.csv'

df = pd.read_csv(path, delimiter=';')

df
# Out:
#       Id экзамена  Id вопроса  № вопроса  \
# 0         3373871    30625752          1
# 1         3373871    30625753          2
# 2         3373871    30625754          3
# 3         3373871    30625755          4
# 4         3373872    30625790          1
# ...           ...         ...        ...
# 9793      3448495    32016351          3
# 9794      3448495    32016352          4
# 9795      3448496    32016387          1
# 9796      3448496    32016388          2
# 9797      3448496    32016389          3
#
#                                           Текст вопроса  \
# 0     <p>Добро пожаловать на экзамен! <br>Вопрос уст...
# 1     <p>Вопрос устной части экзамена. Примите участ...
# 2     <p>Вопрос устной части экзамена. Начните диало...
# 3     <p>Вопрос устной части экзамена. Опишите карти...
# 4     <p>Добро пожаловать на экзамен! <br>Вопрос уст...
# ...                                                 ...
# 9793  <p>Вопрос устной части экзамена. Начните диало...
# ...
