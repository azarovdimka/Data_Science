# %% [markdown]
# # ML Analysis - Система автоматической оценки экзаменов по русскому языку

# %% [markdown]
# Заказчик - компания Sigma поставила задачу разработать модель для автоматичексой оценки ответов иностранных граждан при сдаче экзаммена на знание русского языка.

# %% [markdown]
# Этот notebook объединяет функциональность обработки CSV файлов и машинного обучения для анализа и экспериментов.

# %% [markdown]
# Этот файл:
#
# * принимает на вход тренировочный датасет с данными;
#
# * запрашивает и записывает размер каждого аудиофайла с экзамена;
#
# * производит предобработку и очистку полученных данных;
#
# * анализирует ответ экзаменуемого и выичисляет новые признаки (колонки) и добавляет их в таблицу для будущих предсказаний оценки;
#
# * удаляет лишние ненужные колонки;
#
# * формирует пайплайны для обучения модели;
#
# * выбирает лучшую модель по сетке;
#
# * метрики качества обучения модели представлены в конце файла;
#
# * обученная модель сохраняется в файл.

# %% [markdown]
# код включает три разных файла в компиляции. Для бэкенда веб-приложения, этот код из этого файла должен быть разнесен по трем разным файлам.
#
# * backend\handlers\csv_handler.py
#
# * backend\services\ml_service.py
#
# * ml_models\training\train_model.py

# %% [markdown]
# Это рабочий файл создан для:

# %% [markdown]
# * Исследовательского анализа данных
#
# * Экспериментов с моделями
#
# * Визуализации результатов
#
# * Отладки алгоритмов

# %% [markdown]
# ## Импорты и настройки

# %%
# !pip install mutagen

# %%
import pandas as pd
import numpy as np
import pickle
import re
import io
import os
from typing import List, Dict, Any
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_predict, StratifiedKFold
from sklearn.metrics import mean_absolute_error, accuracy_score, classification_report, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import warnings
import pymorphy3
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, MaxAbsScaler, RobustScaler, OneHotEncoder, OrdinalEncoder, LabelEncoder
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.impute import SimpleImputer 
from phik import phik_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.base import BaseEstimator, TransformerMixin
from mutagen.mp3 import MP3
from collections import Counter

# %%
warnings.filterwarnings('ignore') # чтобы не было красный полей с предупреждениями об устаревших библиотеках

# %matplotlib inline
plt.ion() # принудительное отображение графиков matplotlib в VS Code
pd.set_option('display.max_colwidth', None) # чтобы df колонки были пошире
pd.set_option('display.float_format', '{:.2f}'.format) # округление чисел в df, чтобы числа не печатал экспоненциально
pd.options.display.expand_frame_repr = False # для принта чтобы колонки не переносил рабоатет тольок в vs code, in jupyter notebook получается каша

# %%
path = r'C:\Users\dmi-a\OneDrive\Рабочий стол\DS учеба\Выполненные проекты\rus_exam_site\docs\Данные для кейса.csv'

df = pd.read_csv(path, delimiter=';', encoding='utf-8')

# %%
class AudioProcessor(BaseEstimator, TransformerMixin):
    """Отдельный класс для обработки аудиофайлов"""
    
    def __init__(self, timeout=30):
        self.timeout = timeout
        self.counter = 0
        self.total_files = 0
        
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        X_transformed = X.copy()
        self.counter = 0  # Сброс счетчика
        self.total_files = len(X_transformed)
        
        
        if 'Ссылка на оригинальный файл запис' in X_transformed.columns:
            print("Начинаем скачивать аудиофайлы...")
            X_transformed['Длина_файла'] = X_transformed['Ссылка на оригинальный файл запис'].apply(
                self._get_audio_duration
            )
        else:
            X_transformed['Длина_файла'] = 0
            
        return X_transformed
    
    def _get_audio_duration(self, url):
        """Получение длительности аудиофайла"""
        self.counter += 1

        try:
            response = requests.get(url, timeout=self.timeout)
            response.raise_for_status()
            audio_file = MP3(io.BytesIO(response.content))
            duration = audio_file.info.length if audio_file.info.length else 0
            print(f"{self.counter}/{self.total_files} Длина файла {duration / 60:.2f} мин")
            return duration
        except Exception as e:
            print(f"{self.counter}/{self.total_files} Ошибка загрузки аудио: {type(e).__name__}")
            return 0

# %%
class DataPreprocessor(BaseEstimator, TransformerMixin):
    """Основной препроцессор данных"""
    
    def __init__(self):
        self.morph = None
        self.fitted = False

    
    def fit(self, X, y=None):
        if self.morph is None:
            self.morph = pymorphy3.MorphAnalyzer()
        self.fitted = True
        return self
    
    def transform(self, X):
        if not self.fitted:
            raise ValueError("Transformer must be fitted before transform")
        
        X_transformed = X.copy()
        original_indices = X_transformed.index.copy()  # Сохраняем исходные индексы

        # Очистка текста
        print('Очистка текста')
        X_transformed = self._clean_text_columns(X_transformed)
        
        # Фильтрация пустых ответов
        print('Фильтрация пустых ответов')
        # Вместо удаления - заполняем пустые ответы
        empty_mask = ~X_transformed['Транскрибация ответа'].str.contains(r'[а-яёa-z]', case=False, na=False)
        X_transformed.loc[empty_mask, 'Транскрибация ответа'] = 'пустой ответ'

        
        # Анализ речи
        print('Анализ речи')
        speech_analysis = X_transformed['Транскрибация ответа'].apply(self._analyze_speech_quality)
        
        # Извлечение признаков речи
        print("Создание признаков речи ['Качество_речи', 'Лексическое_разнообразие', 'Словарный_запас', 'noun_ratio', 'verb_ratio', 'adjective_ratio', 'NOUN', 'VERB', 'ADJF']")
        for feature in ['Качество_речи', 'Лексическое_разнообразие', 'Словарный_запас', 
                       'noun_ratio', 'verb_ratio', 'adjective_ratio', 'NOUN', 'VERB', 'ADJF']:
            X_transformed[feature] = speech_analysis.apply(lambda x: x.get(feature, 0))
        
        # Создание дополнительных признаков
        print("Создание дополнительных признаков")
        X_transformed = self._create_advanced_features(X_transformed)
        X_transformed = self._create_interaction_features(X_transformed)
        
        # Удаление ненужных колонок
        # print("Удаление ненужных колонок")
        # columns_to_drop = ['Id экзамена', 'Id вопроса', 'Ссылка на оригинальный файл запис', 
        #                   'Картинка из вопроса']
        # X_transformed = X_transformed.drop(columns=[col for col in columns_to_drop if col in X_transformed.columns])
        
        return X_transformed
    
    def _clean_text_columns(self, df):
        """Очистка текстовых колонок"""
        for col in ['Текст вопроса', 'Транскрибация ответа']:
            if col in df.columns:
                df[col] = df[col].apply(self._clean_text)
        return df
    
    def _clean_text(self, text):
        """Очистка отдельного текста"""
        if pd.isna(text):
            return text
        
        text = str(text)
        text = re.sub(r'<[^>]+>', '', text)  # HTML теги
        text = text.replace('\n', ' ')        # Переносы строк
        text = re.sub(r'\s+', ' ', text)      # Множественные пробелы
        text = text.strip()                   # Пробелы в начале/конце
        
        return text
    
    def _analyze_speech_quality(self, text):
        """Анализ качества речи"""
        if pd.isna(text) or text == '':
            return self._get_default_analysis()
        
        # Очистка и токенизация
        words = re.findall(r'\b\w+\b', str(text).lower())
        
        if not words:
            return self._get_default_analysis()
        
        # Морфологический анализ
        pos_counts = Counter()
        unique_lemmas = set()
        
        for word in words:
            parsed = self.morph.parse(word)[0]
            
            if parsed.tag.POS:
                pos_counts[parsed.tag.POS] += 1
            
            unique_lemmas.add(parsed.normal_form)
        
        total_words = len(words)
        
        # Расчет метрик
        lexical_diversity = len(unique_lemmas) / total_words if total_words > 0 else 0
        noun_ratio = pos_counts.get('NOUN', 0) / total_words
        verb_ratio = pos_counts.get('VERB', 0) / total_words
        adjective_ratio = pos_counts.get('ADJF', 0) / total_words
        
        complexity_score = self._calculate_complexity(pos_counts, total_words)
        
        quality_score = (
            lexical_diversity + verb_ratio + noun_ratio + 
            adjective_ratio + complexity_score
        )
        
        return {
            'Качество_речи': 190 - (quality_score * 100),
            'Лексическое_разнообразие': lexical_diversity,
            'Словарный_запас': len(unique_lemmas),
            'noun_ratio': noun_ratio,
            'verb_ratio': verb_ratio,
            'adjective_ratio': adjective_ratio,
            'NOUN': pos_counts.get('NOUN', 0),
            'VERB': pos_counts.get('VERB', 0),
            'ADJF': pos_counts.get('ADJF', 0),
        }
    
    def _calculate_complexity(self, pos_counts, total_words):
        """Расчет сложности речи"""
        complexity_weights = {
            'ADJF': 1.6, 'ADVB': 1.8, 'GRND': 1.9, 'PREP': 1.2,
            'CONJ': 1.1, 'VERB': 1.4, 'INFN': 1.3, 'PRTF': 1.5, 'PRTS': 1.5
        }
        
        complexity = 0
        for pos, count in pos_counts.items():
            weight = complexity_weights.get(pos, 1.0)
            complexity += (count / total_words) * weight
        
        return min(complexity, 1)
    
    def _create_advanced_features(self, df):
        """Создание продвинутых признаков"""
        # Пересечение вопроса и ответа
        def text_overlap_ratio(row):
            question = str(row['Текст вопроса']).lower()
            answer = str(row['Транскрибация ответа']).lower()
            
            question_words = set(question.split())
            answer_words = set(answer.split())
            
            if len(question_words) == 0:
                return 0
            
            overlap = len(question_words.intersection(answer_words))
            return overlap / len(question_words)
        
        df['question_overlap_ratio'] = df.apply(text_overlap_ratio, axis=1)
        df['Рассуждение'] = (df['question_overlap_ratio'] >= 0.5).astype(int)
        
        # Длина и скорость
        df['Длина_ответа'] = df['Транскрибация ответа'].str.len()
        df['length_ratio'] = df['Длина_ответа'] / df['Длина_ответа'].mean()
        df['length_factor'] = np.where(df['length_ratio'] > 1, 1, -1)
        
        # Скорость речи (только если есть длина файла)
        if 'Длина_файла' in df.columns:
            df['Скорость_речи'] = df['Длина_ответа'] / (df['Длина_файла'] + 1e-6)  # избегаем деления на 0
        else:
            df['Скорость_речи'] = 0
        
        # Уникальные слова и свобода речи
        df['Уникальных_слов'] = df['Транскрибация ответа'].apply(
            lambda x: len(set(str(x).split()))
        )
        df['Свобода_речи'] = df['Уникальных_слов'] / (df['Длина_ответа'] + 1e-6)
        
        # Общий балл качества
        df['quality_score'] = (
            -df['Рассуждение'] * 1.5 +
            df['length_factor'] * 1.5 +
            df['Скорость_речи'] * 1.5
        ) + 5
        
        return df
    
    def _create_interaction_features(self, df):
        """Создание признаков взаимодействия"""
        df['quality_vocab_interaction'] = df['quality_score'] * df['Словарный_запас'] * 2
        df['length_speed_interaction'] = df['Длина_ответа'] * df['Скорость_речи'] * 2
        df['noun_adjf_interaction'] = df['NOUN'] * df['ADJF'] * 2
        df['diversity_unique_interaction'] = df['Лексическое_разнообразие'] * df['Уникальных_слов'] * 2
        
        return df
    
    def _get_default_analysis(self):
        """Значения по умолчанию для пустого текста"""
        return {
            'Качество_речи': 0, 'Лексическое_разнообразие': 0, 'Словарный_запас': 0,
            'noun_ratio': 0, 'verb_ratio': 0, 'adjective_ratio': 0,
            'NOUN': 0, 'VERB': 0, 'ADJF': 0
        }

# %%
# Ограничиваем размер файла для предварительного исследования
# df = df.head(200)

# %%
df.shape
# Out:
# (9798, 8)

# %%
# Новая ячейка для исследовательского анализа
print("=== ПРЕДВАРИТЕЛЬНАЯ ОБРАБОТКА ДЛЯ ИССЛЕДОВАНИЯ ===")

# Создаем копию для исследования
df_research = df.copy()

# Применяем AudioProcessor
print("1. Обработка аудиофайлов...")
audio_processor = AudioProcessor(timeout=30)
df_research = audio_processor.fit_transform(df_research)

# Применяем DataPreprocessor  
print("2. Анализ речи и создание признаков...")
data_preprocessor = DataPreprocessor()
df_research = data_preprocessor.fit_transform(df_research)

print("3. Обработка завершена!")
print(f"Размер обработанного датасета: {df_research.shape}")
print(f"Новые колонки: {[col for col in df_research.columns if col not in df.columns]}")
# Out:
# === ПРЕДВАРИТЕЛЬНАЯ ОБРАБОТКА ДЛЯ ИССЛЕДОВАНИЯ ===
# 1. Обработка аудиофайлов...
# Начинаем скачивать аудиофайлы...
# 1/9798 Длина файла 1.32 мин
# 2/9798 Длина файла 2.08 мин
# 3/9798 Длина файла 3.48 мин
# 4/9798 Длина файла 7.23 мин
# 5/9798 Длина файла 1.98 мин
# 6/9798 Длина файла 6.17 мин
# 7/9798 Длина файла 6.00 мин
# 8/9798 Длина файла 4.23 мин
# 9/9798 Длина файла 2.57 мин
# 10/9798 Длина файла 4.47 мин
# 11/9798 Длина файла 6.21 мин
# 12/9798 Длина файла 4.38 мин
# 13/9798 Длина файла 2.08 мин
# 14/9798 Длина файла 5.85 мин
# 15/9798 Длина файла 6.35 мин
# 16/9798 Длина файла 5.27 мин
# 17/9798 Длина файла 2.55 мин
# 18/9798 Длина файла 5.05 мин
# 19/9798 Длина файла 5.74 мин
# 20/9798 Длина файла 4.64 мин
# 21/9798 Длина файла 2.00 мин
# 22/9798 Длина файла 3.60 мин
# 23/9798 Длина файла 5.35 мин
# 24/9798 Длина файла 5.36 мин
# 25/9798 Длина файла 2.40 мин
# 26/9798 Длина файла 5.95 мин
# 27/9798 Длина файла 6.46 мин
# 28/9798 Длина файла 4.92 мин
# 29/9798 Длина файла 1.58 мин
# 30/9798 Длина файла 2.90 мин
# 31/9798 Длина файла 3.93 мин
# 32/9798 Длина файла 7.10 мин
# 33/9798 Длина файла 1.45 мин
# 34/9798 Длина файла 4.28 мин
# 35/9798 Длина файла 6.07 мин
# 36/9798 Длина файла 5.33 мин
# 37/9798 Длина файла 1.70 мин
# 38/9798 Длина файла 3.70 мин
# 39/9798 Длина файла 5.58 мин
# 40/9798 Длина файла 5.70 мин
# 41/9798 Длина файла 2.62 мин
# 42/9798 Длина файла 6.47 мин
# 43/9798 Длина файла 5.74 мин
# 44/9798 Длина файла 4.50 мин
# 45/9798 Длина файла 1.67 мин
# 46/9798 Длина файла 5.52 мин
# 47/9798 Длина файла 6.52 мин
# 48/9798 Длина файла 5.61 мин
# 49/9798 Длина файла 1.58 мин
# 50/9798 Длина файла 5.35 мин
# 51/9798 Длина файла 6.72 мин
# 52/9798 Длина файла 4.25 мин
# 53/9798 Длина файла 1.27 мин
# 54/9798 Длина файла 2.03 мин
# 55/9798 Длина файла 2.23 мин
# 56/9798 Длина файла 1.36 мин
# 57/9798 Длина файла 2.08 мин
# 58/9798 Длина файла 2.83 мин
# 59/9798 Длина файла 3.37 мин
# 60/9798 Длина файла 2.12 мин
# 61/9798 Длина файла 2.25 мин
# 62/9798 Длина файла 4.38 мин
# 63/9798 Длина файла 5.02 мин
# 64/9798 Длина файла 3.77 мин
# 65/9798 Длина файла 2.02 мин
# 66/9798 Длина файла 3.25 мин
# 67/9798 Длина файла 4.65 мин
# 68/9798 Длина файла 4.92 мин
# 69/9798 Длина файла 1.63 мин
# 70/9798 Длина файла 3.48 мин
# 71/9798 Длина файла 2.49 мин
# 72/9798 Длина файла 1.26 мин
# 73/9798 Длина файла 1.73 мин
# 74/9798 Длина файла 2.70 мин
# 75/9798 Длина файла 2.14 мин
# 76/9798 Длина файла 1.29 мин
# 77/9798 Длина файла 1.42 мин
# 78/9798 Длина файла 2.75 мин
# 79/9798 Длина файла 2.41 мин
# 80/9798 Длина файла 1.55 мин
# 81/9798 Длина файла 1.43 мин
# 82/9798 Длина файла 2.33 мин
# 83/9798 Длина файла 4.02 мин
# 84/9798 Длина файла 3.03 мин
# 85/9798 Длина файла 1.17 мин
# 86/9798 Длина файла 2.15 мин
# 87/9798 Длина файла 2.55 мин
# 88/9798 Длина файла 1.82 мин
# 89/9798 Длина файла 2.07 мин
# 90/9798 Длина файла 3.20 мин
# 91/9798 Длина файла 2.42 мин
# 92/9798 Длина файла 1.38 мин
# 93/9798 Длина файла 2.17 мин
# 94/9798 Длина файла 3.60 мин
# 95/9798 Длина файла 4.80 мин
# 96/9798 Длина файла 6.22 мин
# 97/9798 Длина файла 2.15 мин
# 98/9798 Длина файла 4.48 мин
# 99/9798 Длина файла 6.94 мин
# 100/9798 Длина файла 4.27 мин
# 101/9798 Длина файла 2.07 мин
# 102/9798 Длина файла 4.45 мин
# 103/9798 Длина файла 5.68 мин
# 104/9798 Длина файла 6.30 мин
# 105/9798 Длина файла 1.92 мин
# 106/9798 Длина файла 5.03 мин
# 107/9798 Длина файла 6.02 мин
# 108/9798 Длина файла 6.02 мин
# 109/9798 Длина файла 1.77 мин
# 110/9798 Длина файла 4.48 мин
# 111/9798 Длина файла 6.27 мин
# 112/9798 Длина файла 5.79 мин
# 113/9798 Длина файла 1.80 мин
# 114/9798 Длина файла 6.05 мин
# 115/9798 Длина файла 6.17 мин
# 116/9798 Длина файла 4.89 мин
# 117/9798 Длина файла 1.78 мин
# 118/9798 Длина файла 3.45 мин
# 119/9798 Длина файла 5.77 мин
# 120/9798 Длина файла 5.45 мин
# 121/9798 Длина файла 2.17 мин
# 122/9798 Длина файла 6.03 мин
# 123/9798 Длина файла 6.09 мин
# 124/9798 Длина файла 4.29 мин
# 125/9798 Длина файла 2.23 мин
# 126/9798 Длина файла 4.93 мин
# 127/9798 Длина файла 6.15 мин
# 128/9798 Длина файла 3.82 мин
# 129/9798 Длина файла 1.42 мин
# 130/9798 Длина файла 2.92 мин
# 131/9798 Длина файла 3.98 мин
# 132/9798 Длина файла 7.21 мин
# 133/9798 Длина файла 1.58 мин
# 134/9798 Длина файла 4.78 мин
# 135/9798 Длина файла 5.97 мин
# 136/9798 Длина файла 4.45 мин
# 137/9798 Длина файла 2.45 мин
# 138/9798 Длина файла 3.53 мин
# 139/9798 Длина файла 5.80 мин
# 140/9798 Длина файла 5.57 мин
# 141/9798 Длина файла 1.43 мин
# 142/9798 Длина файла 4.50 мин
# 143/9798 Длина файла 6.23 мин
# 144/9798 Длина файла 5.01 мин
# 145/9798 Длина файла 0.07 мин
# 146/9798 Длина файла 3.02 мин
# 147/9798 Длина файла 5.63 мин
# 148/9798 Длина файла 5.37 мин
# 149/9798 Длина файла 3.77 мин
# 150/9798 Длина файла 2.00 мин
# 151/9798 Длина файла 4.77 мин
# 152/9798 Длина файла 6.10 мин
# 153/9798 Длина файла 5.12 мин
# 154/9798 Длина файла 0.55 мин
# 155/9798 Длина файла 0.65 мин
# 156/9798 Длина файла 0.57 мин
# 157/9798 Длина файла 0.54 мин
# 158/9798 Длина файла 2.02 мин
# 159/9798 Длина файла 6.12 мин
# 160/9798 Длина файла 4.08 мин
# 161/9798 Длина файла 2.87 мин
# 162/9798 Длина файла 2.93 мин
# 163/9798 Длина файла 4.20 мин
# 164/9798 Длина файла 4.90 мин
# 165/9798 Длина файла 5.88 мин
# 166/9798 Длина файла 2.88 мин
# 167/9798 Длина файла 5.28 мин
# 168/9798 Длина файла 5.53 мин
# 169/9798 Длина файла 3.65 мин
# 170/9798 Длина файла 2.33 мин
# 171/9798 Длина файла 5.08 мин
# 172/9798 Длина файла 5.74 мин
# 173/9798 Длина файла 2.36 мин
# 174/9798 Длина файла 1.33 мин
# 175/9798 Длина файла 4.00 мин
# 176/9798 Длина файла 6.48 мин
# 177/9798 Длина файла 4.64 мин
# 178/9798 Длина файла 2.35 мин
# 179/9798 Длина файла 5.28 мин
# 180/9798 Длина файла 5.64 мин
# 181/9798 Длина файла 3.64 мин
# 182/9798 Длина файла 3.35 мин
# 183/9798 Длина файла 6.38 мин
# 184/9798 Длина файла 4.63 мин
# 185/9798 Длина файла 3.16 мин
# 186/9798 Длина файла 2.37 мин
# 187/9798 Длина файла 5.60 мин
# 188/9798 Длина файла 5.23 мин
# 189/9798 Длина файла 5.67 мин
# 190/9798 Длина файла 5.13 мин
# 191/9798 Длина файла 3.58 мин
# 192/9798 Длина файла 1.67 мин
# 193/9798 Длина файла 7.75 мин
# 194/9798 Длина файла 4.25 мин
# 195/9798 Длина файла 3.03 мин
# 196/9798 Длина файла 2.25 мин
# 197/9798 Длина файла 4.93 мин
# 198/9798 Длина файла 5.95 мин
# 199/9798 Длина файла 3.96 мин
# 200/9798 Длина файла 1.78 мин
# 201/9798 Длина файла 3.67 мин
# 202/9798 Длина файла 5.13 мин
# 203/9798 Длина файла 5.13 мин
# 204/9798 Длина файла 1.45 мин
# 205/9798 Длина файла 5.08 мин
# 206/9798 Длина файла 5.08 мин
# 207/9798 Длина файла 1.68 мин
# 208/9798 Длина файла 5.57 мин
# 209/9798 Длина файла 5.73 мин
# 210/9798 Длина файла 4.40 мин
# 211/9798 Длина файла 2.08 мин
# 212/9798 Длина файла 5.17 мин
# 213/9798 Длина файла 6.19 мин
# 214/9798 Длина файла 2.76 мин
# 215/9798 Длина файла 1.83 мин
# 216/9798 Длина файла 5.27 мин
# 217/9798 Длина файла 6.56 мин
# 218/9798 Длина файла 4.49 мин
# 219/9798 Длина файла 2.28 мин
# 220/9798 Длина файла 4.75 мин
# 221/9798 Длина файла 4.23 мин
# 222/9798 Длина файла 2.25 мин
# 223/9798 Длина файла 6.73 мин
# 224/9798 Длина файла 4.52 мин
# 225/9798 Длина файла 1.57 мин
# 226/9798 Длина файла 2.02 мин
# 227/9798 Длина файла 6.87 мин
# 228/9798 Длина файла 4.97 мин
# 229/9798 Длина файла 2.26 мин
# 230/9798 Длина файла 1.63 мин
# 231/9798 Длина файла 3.20 мин
# 232/9798 Длина файла 4.10 мин
# 233/9798 Длина файла 6.57 мин
# 234/9798 Длина файла 1.23 мин
# 235/9798 Длина файла 2.82 мин
# 236/9798 Длина файла 3.75 мин
# 237/9798 Длина файла 7.93 мин
# 238/9798 Длина файла 1.43 мин
# 239/9798 Длина файла 3.80 мин
# 240/9798 Длина файла 5.57 мин
# 241/9798 Длина файла 4.94 мин
# 242/9798 Длина файла 2.67 мин
# 243/9798 Длина файла 6.65 мин
# 244/9798 Длина файла 5.27 мин
# 245/9798 Длина файла 3.92 мин
# 246/9798 Длина файла 2.03 мин
# 247/9798 Длина файла 6.62 мин
# 248/9798 Длина файла 5.38 мин
# 249/9798 Длина файла 3.90 мин
# 250/9798 Длина файла 1.90 мин
# 251/9798 Длина файла 4.75 мин
# 252/9798 Длина файла 6.48 мин
# 253/9798 Длина файла 5.79 мин
# 254/9798 Длина файла 1.38 мин
# 255/9798 Длина файла 4.43 мин
# 256/9798 Длина файла 5.75 мин
# 257/9798 Длина файла 6.18 мин
# 258/9798 Длина файла 2.05 мин
# 259/9798 Длина файла 3.02 мин
# 260/9798 Длина файла 4.75 мин
# 261/9798 Длина файла 5.54 мин
# 262/9798 Длина файла 1.58 мин
# 263/9798 Длина файла 5.35 мин
# 264/9798 Длина файла 6.46 мин
# 265/9798 Длина файла 5.05 мин
# 266/9798 Длина файла 1.68 мин
# 267/9798 Длина файла 4.35 мин
# 268/9798 Длина файла 5.82 мин
# 269/9798 Длина файла 4.65 мин
# 270/9798 Длина файла 1.47 мин
# 271/9798 Длина файла 2.98 мин
# 272/9798 Длина файла 4.37 мин
# 273/9798 Длина файла 6.34 мин
# 274/9798 Длина файла 2.60 мин
# 275/9798 Длина файла 5.07 мин
# 276/9798 Длина файла 5.52 мин
# 277/9798 Длина файла 4.14 мин
# 278/9798 Длина файла 3.33 мин
# 279/9798 Длина файла 6.25 мин
# 280/9798 Длина файла 5.83 мин
# 281/9798 Длина файла 3.06 мин
# 282/9798 Длина файла 2.40 мин
# 283/9798 Длина файла 5.00 мин
# 284/9798 Длина файла 6.20 мин
# 285/9798 Длина файла 4.02 мин
# 286/9798 Длина файла 1.43 мин
# 287/9798 Длина файла 0.32 мин
# 288/9798 Длина файла 0.22 мин
# 289/9798 Длина файла 0.12 мин
# 290/9798 Длина файла 2.33 мин
# 291/9798 Длина файла 6.43 мин
# 292/9798 Длина файла 5.59 мин
# 293/9798 Длина файла 3.99 мин
# 294/9798 Длина файла 1.43 мин
# 295/9798 Длина файла 2.48 мин
# 296/9798 Длина файла 3.42 мин
# 297/9798 Длина файла 6.70 мин
# 298/9798 Длина файла 1.62 мин
# 299/9798 Длина файла 3.48 мин
# 300/9798 Длина файла 4.45 мин
# 301/9798 Длина файла 5.65 мин
# 302/9798 Длина файла 1.70 мин
# 303/9798 Длина файла 3.52 мин
# 304/9798 Длина файла 4.93 мин
# 305/9798 Длина файла 5.28 мин
# 306/9798 Длина файла 1.82 мин
# 307/9798 Длина файла 3.43 мин
# 308/9798 Длина файла 5.07 мин
# 309/9798 Длина файла 1.45 мин
# 310/9798 Длина файла 3.48 мин
# 311/9798 Длина файла 4.92 мин
# 312/9798 Длина файла 5.15 мин
# 313/9798 Длина файла 2.32 мин
# 314/9798 Длина файла 5.38 мин
# 315/9798 Длина файла 6.50 мин
# 316/9798 Длина файла 4.79 мин
# 317/9798 Длина файла 2.40 мин
# 318/9798 Длина файла 4.25 мин
# 319/9798 Длина файла 6.33 мин
# 320/9798 Длина файла 5.19 мин
# 321/9798 Длина файла 1.82 мин
# 322/9798 Длина файла 3.05 мин
# 323/9798 Длина файла 4.40 мин
# 324/9798 Длина файла 5.82 мин
# 325/9798 Длина файла 1.63 мин
# 326/9798 Длина файла 3.20 мин
# 327/9798 Длина файла 4.68 мин
# 328/9798 Длина файла 5.62 мин
# 329/9798 Длина файла 1.67 мин
# 330/9798 Длина файла 2.98 мин
# 331/9798 Длина файла 4.60 мин
# 332/9798 Длина файла 5.57 мин
# 333/9798 Длина файла 2.08 мин
# 334/9798 Длина файла 4.93 мин
# 335/9798 Длина файла 5.35 мин
# 336/9798 Длина файла 3.53 мин
# 337/9798 Длина файла 1.95 мин
# 338/9798 Длина файла 4.02 мин
# 339/9798 Длина файла 5.05 мин
# 340/9798 Длина файла 5.17 мин
# 341/9798 Длина файла 2.58 мин
# 342/9798 Длина файла 5.23 мин
# 343/9798 Длина файла 4.86 мин
# 344/9798 Длина файла 3.21 мин
# 345/9798 Длина файла 1.87 мин
# 346/9798 Длина файла 3.03 мин
# 347/9798 Длина файла 4.25 мин
# 348/9798 Длина файла 5.88 мин
# 349/9798 Длина файла 1.68 мин
# 350/9798 Длина файла 3.05 мин
# 351/9798 Длина файла 4.13 мин
# 352/9798 Длина файла 6.00 мин
# 353/9798 Длина файла 1.55 мин
# 354/9798 Длина файла 3.88 мин
# 355/9798 Длина файла 5.45 мин
# 356/9798 Длина файла 5.33 мин
# 357/9798 Длина файла 1.28 мин
# 358/9798 Длина файла 2.12 мин
# 359/9798 Длина файла 2.72 мин
# 360/9798 Длина файла 7.43 мин
# 361/9798 Длина файла 1.90 мин
# 362/9798 Длина файла 2.72 мин
# 363/9798 Длина файла 3.98 мин
# 364/9798 Длина файла 6.13 мин
# 365/9798 Длина файла 1.93 мин
# 366/9798 Длина файла 2.65 мин
# 367/9798 Длина файла 3.98 мин
# 368/9798 Длина файла 4.17 мин
# 369/9798 Длина файла 5.02 мин
# 370/9798 Длина файла 5.13 мин
# 371/9798 Длина файла 3.52 мин
# 372/9798 Длина файла 3.07 мин
# 373/9798 Длина файла 4.70 мин
# 374/9798 Длина файла 5.45 мин
# 375/9798 Длина файла 3.83 мин
# 376/9798 Длина файла 1.43 мин
# 377/9798 Длина файла 2.60 мин
# 378/9798 Длина файла 3.82 мин
# 379/9798 Длина файла 6.33 мин
# 380/9798 Длина файла 1.33 мин
# 381/9798 Длина файла 2.93 мин
# 382/9798 Длина файла 4.30 мин
# 383/9798 Длина файла 5.78 мин
# 384/9798 Длина файла 2.17 мин
# 385/9798 Длина файла 3.77 мин
# 386/9798 Длина файла 4.83 мин
# 387/9798 Длина файла 5.37 мин
# 388/9798 Длина файла 1.62 мин
# 389/9798 Длина файла 2.83 мин
# 390/9798 Длина файла 4.05 мин
# 391/9798 Длина файла 6.40 мин
# 392/9798 Длина файла 1.45 мин
# 393/9798 Длина файла 3.27 мин
# 394/9798 Длина файла 4.63 мин
# 395/9798 Длина файла 5.48 мин
# 396/9798 Длина файла 2.35 мин
# 397/9798 Длина файла 3.55 мин
# 398/9798 Длина файла 4.70 мин
# 399/9798 Длина файла 5.62 мин
# 400/9798 Длина файла 2.42 мин
# 401/9798 Длина файла 3.35 мин
# 402/9798 Длина файла 3.11 мин
# 403/9798 Длина файла 2.58 мин
# 404/9798 Длина файла 4.45 мин
# 405/9798 Длина файла 5.77 мин
# 406/9798 Длина файла 4.37 мин
# 407/9798 Длина файла 2.35 мин
# 408/9798 Длина файла 5.12 мин
# 409/9798 Длина файла 5.20 мин
# 410/9798 Длина файла 3.99 мин
# 411/9798 Длина файла 1.23 мин
# 412/9798 Длина файла 3.92 мин
# 413/9798 Длина файла 5.67 мин
# 414/9798 Длина файла 4.57 мин
# 415/9798 Длина файла 2.00 мин
# 416/9798 Длина файла 5.58 мин
# 417/9798 Длина файла 4.55 мин
# 418/9798 Длина файла 1.48 мин
# 419/9798 Длина файла 2.47 мин
# 420/9798 Длина файла 3.95 мин
# 421/9798 Длина файла 6.33 мин
# 422/9798 Длина файла 1.30 мин
# 423/9798 Длина файла 5.30 мин
# 424/9798 Длина файла 4.99 мин
# 425/9798 Длина файла 3.77 мин
# 426/9798 Длина файла 2.15 мин
# 427/9798 Длина файла 5.98 мин
# 428/9798 Длина файла 4.81 мин
# 429/9798 Длина файла 2.93 мин
# 430/9798 Длина файла 1.63 мин
# 431/9798 Длина файла 3.47 мин
# 432/9798 Длина файла 4.83 мин
# 433/9798 Длина файла 5.34 мин
# 434/9798 Длина файла 1.90 мин
# 435/9798 Длина файла 5.02 мин
# 436/9798 Длина файла 5.20 мин
# 437/9798 Длина файла 4.23 мин
# 438/9798 Длина файла 1.40 мин
# 439/9798 Длина файла 5.17 мин
# 440/9798 Длина файла 4.99 мин
# 441/9798 Длина файла 3.67 мин
# 442/9798 Длина файла 1.65 мин
# 443/9798 Длина файла 3.92 мин
# 444/9798 Длина файла 5.00 мин
# 445/9798 Длина файла 5.15 мин
# 446/9798 Длина файла 5.40 мин
# 447/9798 Длина файла 4.92 мин
# 448/9798 Длина файла 3.75 мин
# 449/9798 Длина файла 2.03 мин
# 450/9798 Длина файла 4.93 мин
# 451/9798 Длина файла 3.49 мин
# 452/9798 Длина файла 1.38 мин
# 453/9798 Длина файла 2.80 мин
# 454/9798 Длина файла 3.90 мин
# 455/9798 Длина файла 6.48 мин
# 456/9798 Длина файла 3.38 мин
# 457/9798 Длина файла 5.37 мин
# 458/9798 Длина файла 4.90 мин
# 459/9798 Длина файла 3.02 мин
# 460/9798 Длина файла 1.68 мин
# 461/9798 Длина файла 3.27 мин
# 462/9798 Длина файла 5.28 мин
# 463/9798 Длина файла 5.27 мин
# 464/9798 Длина файла 2.02 мин
# 465/9798 Длина файла 3.38 мин
# 466/9798 Длина файла 5.25 мин
# 467/9798 Длина файла 5.21 мин
# 468/9798 Длина файла 1.83 мин
# 469/9798 Длина файла 3.43 мин
# 470/9798 Длина файла 4.70 мин
# 471/9798 Длина файла 5.44 мин
# 472/9798 Длина файла 1.58 мин
# 473/9798 Длина файла 7.52 мин
# 474/9798 Длина файла 4.98 мин
# 475/9798 Длина файла 3.86 мин
# 476/9798 Длина файла 2.78 мин
# 477/9798 Длина файла 4.98 мин
# 478/9798 Длина файла 6.08 мин
# 479/9798 Длина файла 3.05 мин
# 480/9798 Длина файла 3.63 мин
# 481/9798 Длина файла 6.35 мин
# 482/9798 Длина файла 4.37 мин
# 483/9798 Длина файла 2.26 мин
# 484/9798 Длина файла 1.95 мин
# 485/9798 Длина файла 6.48 мин
# 486/9798 Длина файла 4.69 мин
# 487/9798 Длина файла 3.28 мин
# 488/9798 Длина файла 2.10 мин
# 489/9798 Длина файла 5.57 мин
# 490/9798 Длина файла 5.30 мин
# 491/9798 Длина файла 3.57 мин
# 492/9798 Длина файла 3.20 мин
# 493/9798 Длина файла 2.66 мин
# 494/9798 Длина файла 0.76 мин
# 495/9798 Длина файла 1.70 мин
# 496/9798 Длина файла 5.92 мин
# 497/9798 Длина файла 5.34 мин
# 498/9798 Длина файла 3.12 мин
# 499/9798 Длина файла 2.52 мин
# 500/9798 Длина файла 6.23 мин
# 501/9798 Длина файла 6.36 мин
# 502/9798 Длина файла 2.04 мин
# 503/9798 Длина файла 3.22 мин
# 504/9798 Длина файла 6.38 мин
# 505/9798 Длина файла 4.92 мин
# 506/9798 Длина файла 2.52 мин
# 507/9798 Длина файла 1.42 мин
# 508/9798 Длина файла 4.00 мин
# 509/9798 Длина файла 5.32 мин
# 510/9798 Длина файла 4.92 мин
# 511/9798 Длина файла 1.75 мин
# 512/9798 Длина файла 2.53 мин
# 513/9798 Длина файла 3.55 мин
# 514/9798 Длина файла 6.77 мин
# 515/9798 Длина файла 1.03 мин
# 516/9798 Длина файла 3.60 мин
# 517/9798 Длина файла 4.98 мин
# 518/9798 Длина файла 5.21 мин
# 519/9798 Длина файла 1.40 мин
# 520/9798 Длина файла 2.93 мин
# 521/9798 Длина файла 4.73 мин
# 522/9798 Длина файла 5.48 мин
# 523/9798 Длина файла 2.30 мин
# 524/9798 Длина файла 4.40 мин
# 525/9798 Длина файла 5.97 мин
# 526/9798 Длина файла 4.13 мин
# 527/9798 Длина файла 1.70 мин
# 528/9798 Длина файла 3.65 мин
# 529/9798 Длина файла 5.22 мин
# 530/9798 Длина файла 5.23 мин
# 531/9798 Длина файла 1.32 мин
# 532/9798 Длина файла 3.67 мин
# 533/9798 Длина файла 4.75 мин
# 534/9798 Длина файла 5.39 мин
# 535/9798 Длина файла 2.07 мин
# 536/9798 Длина файла 3.67 мин
# 537/9798 Длина файла 5.00 мин
# 538/9798 Длина файла 5.36 мин
# 539/9798 Длина файла 1.60 мин
# 540/9798 Длина файла 2.67 мин
# 541/9798 Длина файла 3.85 мин
# 542/9798 Длина файла 6.30 мин
# 543/9798 Длина файла 2.08 мин
# 544/9798 Длина файла 4.83 мин
# 545/9798 Длина файла 6.82 мин
# 546/9798 Длина файла 3.93 мин
# 547/9798 Длина файла 0.24 мин
# 548/9798 Длина файла 0.06 мин
# 549/9798 Длина файла 1.65 мин
# 550/9798 Длина файла 3.28 мин
# 551/9798 Длина файла 4.67 мин
# 552/9798 Длина файла 6.16 мин
# 553/9798 Длина файла 1.97 мин
# 554/9798 Длина файла 3.77 мин
# 555/9798 Длина файла 6.02 мин
# 556/9798 Длина файла 4.12 мин
# 557/9798 Длина файла 1.62 мин
# 558/9798 Длина файла 5.47 мин
# 559/9798 Длина файла 6.86 мин
# 560/9798 Длина файла 4.11 мин
# 561/9798 Длина файла 1.95 мин
# 562/9798 Длина файла 6.53 мин
# 563/9798 Длина файла 5.58 мин
# 564/9798 Длина файла 3.81 мин
# 565/9798 Длина файла 5.78 мин
# 566/9798 Длина файла 6.57 мин
# 567/9798 Длина файла 4.67 мин
# 568/9798 Длина файла 1.70 мин
# 569/9798 Длина файла 3.40 мин
# 570/9798 Длина файла 5.45 мин
# 571/9798 Длина файла 6.10 мин
# 572/9798 Длина файла 1.98 мин
# 573/9798 Длина файла 2.90 мин
# 574/9798 Длина файла 4.15 мин
# 575/9798 Длина файла 2.23 мин
# 576/9798 Длина файла 4.23 мин
# 577/9798 Длина файла 5.75 мин
# 578/9798 Длина файла 4.56 мин
# 579/9798 Длина файла 1.92 мин
# 580/9798 Длина файла 4.55 мин
# 581/9798 Длина файла 5.72 мин
# 582/9798 Длина файла 4.31 мин
# 583/9798 Длина файла 2.43 мин
# 584/9798 Длина файла 4.70 мин
# 585/9798 Длина файла 5.55 мин
# 586/9798 Длина файла 3.85 мин
# 587/9798 Длина файла 1.82 мин
# 588/9798 Длина файла 4.10 мин
# 589/9798 Длина файла 5.40 мин
# 590/9798 Длина файла 4.73 мин
# 591/9798 Длина файла 1.97 мин
# 592/9798 Длина файла 4.18 мин
# 593/9798 Длина файла 5.63 мин
# 594/9798 Длина файла 4.50 мин
# 595/9798 Длина файла 2.12 мин
# 596/9798 Длина файла 5.53 мин
# 597/9798 Длина файла 5.24 мин
# 598/9798 Длина файла 4.14 мин
# 599/9798 Длина файла 2.88 мин
# 600/9798 Длина файла 5.75 мин
# 601/9798 Длина файла 4.40 мин
# 602/9798 Длина файла 2.80 мин
# 603/9798 Длина файла 1.62 мин
# 604/9798 Длина файла 2.57 мин
# 605/9798 Длина файла 4.27 мин
# 606/9798 Длина файла 5.84 мин
# 607/9798 Длина файла 2.53 мин
# 608/9798 Длина файла 4.60 мин
# 609/9798 Длина файла 5.70 мин
# 610/9798 Длина файла 4.99 мин
# 611/9798 Длина файла 1.60 мин
# 612/9798 Длина файла 3.00 мин
# 613/9798 Длина файла 4.37 мин
# 614/9798 Длина файла 5.79 мин
# 615/9798 Длина файла 1.53 мин
# 616/9798 Длина файла 3.68 мин
# 617/9798 Длина файла 5.45 мин
# 618/9798 Длина файла 4.82 мин
# 619/9798 Длина файла 1.80 мин
# 620/9798 Длина файла 3.98 мин
# 621/9798 Длина файла 4.11 мин
# 622/9798 Длина файла 2.68 мин
# 623/9798 Длина файла 4.87 мин
# 624/9798 Длина файла 5.30 мин
# 625/9798 Длина файла 3.40 мин
# 626/9798 Длина файла 1.40 мин
# 627/9798 Длина файла 2.28 мин
# 628/9798 Длина файла 4.27 мин
# 629/9798 Длина файла 5.94 мин
# 630/9798 Длина файла 1.72 мин
# 631/9798 Длина файла 4.25 мин
# 632/9798 Длина файла 5.55 мин
# 633/9798 Длина файла 4.62 мин
# 634/9798 Длина файла 1.93 мин
# 635/9798 Длина файла 4.63 мин
# 636/9798 Длина файла 5.48 мин
# 637/9798 Длина файла 4.45 мин
# 638/9798 Длина файла 4.38 мин
# 639/9798 Длина файла 5.55 мин
# 640/9798 Длина файла 4.67 мин
# 641/9798 Длина файла 2.43 мин
# 642/9798 Длина файла 3.22 мин
# 643/9798 Длина файла 4.80 мин
# 644/9798 Длина файла 1.78 мин
# 645/9798 Длина файла 2.53 мин
# 646/9798 Длина файла 3.97 мин
# 647/9798 Длина файла 6.39 мин
# 648/9798 Длина файла 1.73 мин
# 649/9798 Длина файла 2.63 мин
# 650/9798 Длина файла 4.12 мин
# 651/9798 Длина файла 6.25 мин
# 652/9798 Длина файла 1.45 мин
# 653/9798 Длина файла 2.38 мин
# 654/9798 Длина файла 3.65 мин
# 655/9798 Длина файла 2.03 мин
# 656/9798 Длина файла 3.17 мин
# 657/9798 Длина файла 4.87 мин
# 658/9798 Длина файла 5.32 мин
# 659/9798 Длина файла 1.47 мин
# 660/9798 Длина файла 2.52 мин
# 661/9798 Длина файла 3.92 мин
# 662/9798 Длина файла 2.03 мин
# 663/9798 Длина файла 3.68 мин
# 664/9798 Длина файла 6.12 мин
# 665/9798 Длина файла 4.25 мин
# 666/9798 Длина файла 2.78 мин
# 667/9798 Длина файла 4.12 мин
# 668/9798 Длина файла 5.45 мин
# 669/9798 Длина файла 4.82 мин
# 670/9798 Длина файла 1.92 мин
# 671/9798 Длина файла 4.48 мин
# 672/9798 Длина файла 5.72 мин
# 673/9798 Длина файла 4.02 мин
# 674/9798 Длина файла 2.42 мин
# 675/9798 Длина файла 3.65 мин
# 676/9798 Длина файла 5.17 мин
# 677/9798 Длина файла 5.07 мин
# 678/9798 Длина файла 1.87 мин
# 679/9798 Длина файла 2.92 мин
# 680/9798 Длина файла 4.22 мин
# 681/9798 Длина файла 5.90 мин
# 682/9798 Длина файла 2.03 мин
# 683/9798 Длина файла 5.77 мин
# 684/9798 Длина файла 4.93 мин
# 685/9798 Длина файла 2.89 мин
# 686/9798 Длина файла 2.45 мин
# 687/9798 Длина файла 5.77 мин
# 688/9798 Длина файла 5.00 мин
# 689/9798 Длина файла 3.58 мин
# 690/9798 Длина файла 1.20 мин
# 691/9798 Длина файла 5.17 мин
# 692/9798 Длина файла 5.68 мин
# 693/9798 Длина файла 3.47 мин
# 694/9798 Длина файла 1.57 мин
# 695/9798 Длина файла 5.40 мин
# 696/9798 Длина файла 5.40 мин
# 697/9798 Длина файла 2.94 мин
# 698/9798 Длина файла 2.07 мин
# 699/9798 Длина файла 5.37 мин
# 700/9798 Длина файла 5.41 мин
# 701/9798 Длина файла 1.63 мин
# 702/9798 Длина файла 4.83 мин
# 703/9798 Длина файла 6.04 мин
# 704/9798 Длина файла 4.66 мин
# 705/9798 Длина файла 2.97 мин
# 706/9798 Длина файла 5.18 мин
# 707/9798 Длина файла 5.56 мин
# 708/9798 Длина файла 2.05 мин
# 709/9798 Длина файла 5.35 мин
# 710/9798 Длина файла 5.61 мин
# 711/9798 Длина файла 2.31 мин
# 712/9798 Длина файла 1.52 мин
# 713/9798 Длина файла 6.03 мин
# 714/9798 Длина файла 5.37 мин
# 715/9798 Длина файла 4.42 мин
# 716/9798 Длина файла 2.23 мин
# 717/9798 Длина файла 4.68 мин
# 718/9798 Длина файла 6.31 мин
# 719/9798 Длина файла 4.61 мин
# 720/9798 Длина файла 2.70 мин
# 721/9798 Длина файла 5.20 мин
# 722/9798 Длина файла 6.06 мин
# 723/9798 Длина файла 3.24 мин
# 724/9798 Длина файла 2.15 мин
# 725/9798 Длина файла 4.85 мин
# 726/9798 Длина файла 3.63 мин
# 727/9798 Длина файла 2.02 мин
# 728/9798 Длина файла 4.67 мин
# 729/9798 Длина файла 6.52 мин
# 730/9798 Длина файла 4.42 мин
# 731/9798 Длина файла 2.85 мин
# 732/9798 Длина файла 6.42 мин
# 733/9798 Длина файла 3.53 мин
# 734/9798 Длина файла 2.38 мин
# 735/9798 Длина файла 5.32 мин
# 736/9798 Длина файла 5.89 мин
# 737/9798 Длина файла 3.90 мин
# 738/9798 Длина файла 1.62 мин
# 739/9798 Длина файла 3.70 мин
# 740/9798 Длина файла 5.43 мин
# 741/9798 Длина файла 4.70 мин
# 742/9798 Длина файла 2.35 мин
# 743/9798 Длина файла 4.85 мин
# 744/9798 Длина файла 5.50 мин
# 745/9798 Длина файла 4.04 мин
# 746/9798 Длина файла 1.33 мин
# 747/9798 Длина файла 2.75 мин
# 748/9798 Длина файла 3.92 мин
# 749/9798 Длина файла 6.20 мин
# 750/9798 Длина файла 1.98 мин
# 751/9798 Длина файла 4.18 мин
# 752/9798 Длина файла 5.30 мин
# 753/9798 Длина файла 4.92 мин
# 754/9798 Длина файла 1.75 мин
# 755/9798 Длина файла 6.38 мин
# 756/9798 Длина файла 4.29 мин
# 757/9798 Длина файла 2.16 мин
# 758/9798 Длина файла 2.12 мин
# 759/9798 Длина файла 5.60 мин
# 760/9798 Длина файла 4.65 мин
# 761/9798 Длина файла 3.17 мин
# 762/9798 Длина файла 1.87 мин
# 763/9798 Длина файла 5.63 мин
# 764/9798 Длина файла 4.58 мин
# 765/9798 Длина файла 3.36 мин
# 766/9798 Длина файла 1.98 мин
# 767/9798 Длина файла 3.58 мин
# 768/9798 Длина файла 5.17 мин
# 769/9798 Длина файла 4.97 мин
# 770/9798 Длина файла 2.50 мин
# 771/9798 Длина файла 3.45 мин
# 772/9798 Длина файла 5.27 мин
# 773/9798 Длина файла 4.97 мин
# 774/9798 Длина файла 1.48 мин
# 775/9798 Длина файла 6.20 мин
# 776/9798 Длина файла 5.94 мин
# 777/9798 Длина файла 3.96 мин
# 778/9798 Длина файла 1.97 мин
# 779/9798 Длина файла 4.73 мин
# 780/9798 Длина файла 5.55 мин
# 781/9798 Длина файла 4.48 мин
# 782/9798 Длина файла 1.82 мин
# 783/9798 Длина файла 5.98 мин
# 784/9798 Длина файла 4.25 мин
# 785/9798 Длина файла 2.77 мин
# 786/9798 Длина файла 1.97 мин
# 787/9798 Длина файла 5.00 мин
# 788/9798 Длина файла 5.37 мин
# 789/9798 Длина файла 1.80 мин
# 790/9798 Длина файла 3.12 мин
# 791/9798 Длина файла 5.48 мин
# 792/9798 Длина файла 5.14 мин
# 793/9798 Длина файла 2.07 мин
# 794/9798 Длина файла 5.63 мин
# 795/9798 Длина файла 5.49 мин
# 796/9798 Длина файла 3.39 мин
# 797/9798 Длина файла 1.87 мин
# 798/9798 Длина файла 3.15 мин
# 799/9798 Длина файла 5.08 мин
# 800/9798 Длина файла 5.61 мин
# 801/9798 Длина файла 1.92 мин
# 802/9798 Длина файла 2.92 мин
# 803/9798 Длина файла 4.22 мин
# 804/9798 Длина файла 5.95 мин
# 805/9798 Длина файла 1.82 мин
# 806/9798 Длина файла 2.62 мин
# 807/9798 Длина файла 3.60 мин
# 808/9798 Длина файла 6.77 мин
# 809/9798 Длина файла 1.82 мин
# 810/9798 Длина файла 2.83 мин
# 811/9798 Длина файла 3.95 мин
# 812/9798 Длина файла 6.23 мин
# 813/9798 Длина файла 2.37 мин
# 814/9798 Длина файла 3.20 мин
# 815/9798 Длина файла 4.17 мин
# 816/9798 Длина файла 5.93 мин
# 817/9798 Длина файла 3.32 мин
# 818/9798 Длина файла 4.35 мин
# 819/9798 Длина файла 5.78 мин
# 820/9798 Длина файла 4.74 мин
# 821/9798 Длина файла 2.57 мин
# 822/9798 Длина файла 3.92 мин
# 823/9798 Длина файла 5.52 мин
# 824/9798 Длина файла 4.97 мин
# 825/9798 Длина файла 1.53 мин
# 826/9798 Длина файла 2.77 мин
# 827/9798 Длина файла 3.47 мин
# 828/9798 Длина файла 6.77 мин
# 829/9798 Длина файла 1.28 мин
# 830/9798 Длина файла 2.08 мин
# 831/9798 Длина файла 2.95 мин
# 832/9798 Длина файла 7.65 мин
# 833/9798 Длина файла 1.53 мин
# 834/9798 Длина файла 2.35 мин
# 835/9798 Длина файла 3.67 мин
# 836/9798 Длина файла 6.48 мин
# 837/9798 Длина файла 1.92 мин
# 838/9798 Длина файла 2.65 мин
# 839/9798 Длина файла 4.00 мин
# 840/9798 Длина файла 6.75 мин
# 841/9798 Длина файла 2.18 мин
# 842/9798 Длина файла 3.57 мин
# 843/9798 Длина файла 4.80 мин
# 844/9798 Длина файла 7.18 мин
# 845/9798 Длина файла 2.35 мин
# 846/9798 Длина файла 3.90 мин
# 847/9798 Длина файла 4.83 мин
# 848/9798 Длина файла 5.33 мин
# 849/9798 Длина файла 1.45 мин
# 850/9798 Длина файла 2.45 мин
# 851/9798 Длина файла 3.87 мин
# 852/9798 Длина файла 6.32 мин
# 853/9798 Длина файла 5.25 мин
# 854/9798 Длина файла 5.07 мин
# 855/9798 Длина файла 3.47 мин
# 856/9798 Длина файла 0.05 мин
# 857/9798 Длина файла 1.42 мин
# 858/9798 Длина файла 3.38 мин
# 859/9798 Длина файла 5.43 мин
# 860/9798 Длина файла 4.71 мин
# 861/9798 Длина файла 2.97 мин
# 862/9798 Длина файла 4.00 мин
# 863/9798 Длина файла 6.03 мин
# 864/9798 Длина файла 4.39 мин
# 865/9798 Длина файла 1.42 мин
# 866/9798 Длина файла 3.10 мин
# 867/9798 Длина файла 4.38 мин
# 868/9798 Длина файла 6.08 мин
# 869/9798 Длина файла 1.93 мин
# 870/9798 Длина файла 3.73 мин
# 871/9798 Длина файла 5.23 мин
# 872/9798 Длина файла 4.90 мин
# 873/9798 Длина файла 2.60 мин
# 874/9798 Длина файла 4.12 мин
# 875/9798 Длина файла 5.45 мин
# 876/9798 Длина файла 2.82 мин
# 877/9798 Длина файла 3.93 мин
# 878/9798 Длина файла 6.73 мин
# 879/9798 Длина файла 5.41 мин
# 880/9798 Длина файла 2.27 мин
# 881/9798 Длина файла 3.68 мин
# 882/9798 Длина файла 4.50 мин
# 883/9798 Длина файла 5.82 мин
# 884/9798 Длина файла 1.47 мин
# 885/9798 Длина файла 3.97 мин
# 886/9798 Длина файла 5.97 мин
# 887/9798 Длина файла 4.16 мин
# 888/9798 Длина файла 2.40 мин
# 889/9798 Длина файла 5.93 мин
# 890/9798 Длина файла 4.86 мин
# 891/9798 Длина файла 3.19 мин
# 892/9798 Длина файла 2.23 мин
# 893/9798 Длина файла 5.53 мин
# 894/9798 Длина файла 4.84 мин
# 895/9798 Длина файла 3.10 мин
# 896/9798 Длина файла 2.93 мин
# 897/9798 Длина файла 4.37 мин
# 898/9798 Длина файла 5.63 мин
# 899/9798 Длина файла 4.84 мин
# 900/9798 Длина файла 1.33 мин
# 901/9798 Длина файла 3.23 мин
# 902/9798 Длина файла 4.95 мин
# 903/9798 Длина файла 6.54 мин
# 904/9798 Длина файла 5.18 мин
# 905/9798 Длина файла 5.14 мин
# 906/9798 Длина файла 3.99 мин
# 907/9798 Длина файла 2.17 мин
# 908/9798 Длина файла 4.65 мин
# 909/9798 Длина файла 5.69 мин
# 910/9798 Длина файла 1.12 мин
# 911/9798 Длина файла 3.20 мин
# 912/9798 Длина файла 4.43 мин
# 913/9798 Длина файла 5.75 мин
# 914/9798 Длина файла 2.28 мин
# 915/9798 Длина файла 3.50 мин
# 916/9798 Длина файла 6.70 мин
# 917/9798 Длина файла 1.63 мин
# 918/9798 Длина файла 4.37 мин
# 919/9798 Длина файла 5.78 мин
# 920/9798 Длина файла 4.11 мин
# 921/9798 Длина файла 1.58 мин
# 922/9798 Длина файла 2.78 мин
# 923/9798 Длина файла 3.82 мин
# 924/9798 Длина файла 6.30 мин
# 925/9798 Длина файла 1.65 мин
# 926/9798 Длина файла 5.10 мин
# 927/9798 Длина файла 5.08 мин
# 928/9798 Длина файла 4.15 мин
# 929/9798 Длина файла 1.35 мин
# 930/9798 Длина файла 3.27 мин
# 931/9798 Длина файла 4.65 мин
# 932/9798 Длина файла 5.72 мин
# 933/9798 Длина файла 1.75 мин
# 934/9798 Длина файла 5.98 мин
# 935/9798 Длина файла 5.29 мин
# 936/9798 Длина файла 2.84 мин
# 937/9798 Длина файла 1.83 мин
# 938/9798 Длина файла 4.43 мин
# 939/9798 Длина файла 5.38 мин
# 940/9798 Длина файла 5.07 мин
# 941/9798 Длина файла 1.48 мин
# 942/9798 Длина файла 2.93 мин
# 943/9798 Длина файла 5.00 мин
# 944/9798 Длина файла 5.87 мин
# 945/9798 Длина файла 5.90 мин
# 946/9798 Длина файла 2.83 мин
# 947/9798 Длина файла 2.42 мин
# 948/9798 Длина файла 5.40 мин
# 949/9798 Длина файла 5.43 мин
# 950/9798 Длина файла 3.66 мин
# 951/9798 Длина файла 1.55 мин
# 952/9798 Длина файла 4.00 мин
# 953/9798 Длина файла 5.35 мин
# 954/9798 Длина файла 4.95 мин
# 955/9798 Длина файла 4.30 мин
# 956/9798 Длина файла 6.05 мин
# 957/9798 Длина файла 4.92 мин
# 958/9798 Длина файла 3.47 мин
# 959/9798 Длина файла 2.02 мин
# 960/9798 Длина файла 3.25 мин
# 961/9798 Длина файла 4.73 мин
# 962/9798 Длина файла 5.84 мин
# 963/9798 Длина файла 1.97 мин
# 964/9798 Длина файла 3.62 мин
# 965/9798 Длина файла 5.35 мин
# 966/9798 Длина файла 4.92 мин
# 967/9798 Длина файла 1.97 мин
# 968/9798 Длина файла 3.18 мин
# 969/9798 Длина файла 4.50 мин
# 970/9798 Длина файла 6.48 мин
# 971/9798 Длина файла 4.43 мин
# 972/9798 Длина файла 6.80 мин
# 973/9798 Длина файла 4.52 мин
# 974/9798 Длина файла 2.32 мин
# 975/9798 Длина файла 2.25 мин
# 976/9798 Длина файла 4.07 мин
# 977/9798 Длина файла 6.72 мин
# 978/9798 Длина файла 4.52 мин
# 979/9798 Длина файла 1.80 мин
# 980/9798 Длина файла 2.92 мин
# 981/9798 Длина файла 4.62 мин
# 982/9798 Длина файла 6.33 мин
# 983/9798 Длина файла 2.45 мин
# 984/9798 Длина файла 4.40 мин
# 985/9798 Длина файла 6.88 мин
# 986/9798 Длина файла 4.68 мин
# 987/9798 Длина файла 2.57 мин
# 988/9798 Длина файла 4.03 мин
# 989/9798 Длина файла 6.42 мин
# 990/9798 Длина файла 4.50 мин
# 991/9798 Длина файла 1.63 мин
# 992/9798 Длина файла 4.43 мин
# 993/9798 Длина файла 5.68 мин
# 994/9798 Длина файла 3.87 мин
# 995/9798 Длина файла 2.07 мин
# 996/9798 Длина файла 4.65 мин
# 997/9798 Длина файла 5.84 мин
# 998/9798 Длина файла 3.94 мин
# 999/9798 Длина файла 2.62 мин
# 1000/9798 Длина файла 5.10 мин
# 1001/9798 Длина файла 5.65 мин
# 1002/9798 Длина файла 3.72 мин
# 1003/9798 Длина файла 3.03 мин
# 1004/9798 Длина файла 6.00 мин
# 1005/9798 Длина файла 4.21 мин
# 1006/9798 Длина файла 3.08 мин
# 1007/9798 Длина файла 7.17 мин
# 1008/9798 Длина файла 3.77 мин
# 1009/9798 Длина файла 2.44 мин
# 1010/9798 Длина файла 2.15 мин
# 1011/9798 Длина файла 5.28 мин
# 1012/9798 Длина файла 5.78 мин
# 1013/9798 Длина файла 3.93 мин
# 1014/9798 Длина файла 1.88 мин
# 1015/9798 Длина файла 4.17 мин
# 1016/9798 Длина файла 5.43 мин
# 1017/9798 Длина файла 5.21 мин
# 1018/9798 Длина файла 1.73 мин
# 1019/9798 Длина файла 7.15 мин
# 1020/9798 Длина файла 4.71 мин
# 1021/9798 Длина файла 2.14 мин
# 1022/9798 Длина файла 2.68 мин
# 1023/9798 Длина файла 6.05 мин
# 1024/9798 Длина файла 4.84 мин
# 1025/9798 Длина файла 3.22 мин
# 1026/9798 Длина файла 2.08 мин
# 1027/9798 Длина файла 5.08 мин
# 1028/9798 Длина файла 5.72 мин
# 1029/9798 Длина файла 2.90 мин
# 1030/9798 Длина файла 2.68 мин
# 1031/9798 Длина файла 4.40 мин
# 1032/9798 Длина файла 2.12 мин
# 1033/9798 Длина файла 1.87 мин
# 1034/9798 Длина файла 5.35 мин
# 1035/9798 Длина файла 5.74 мин
# 1036/9798 Длина файла 3.94 мин
# 1037/9798 Длина файла 1.33 мин
# 1038/9798 Длина файла 3.58 мин
# 1039/9798 Длина файла 4.62 мин
# 1040/9798 Длина файла 5.91 мин
# 1041/9798 Длина файла 1.57 мин
# 1042/9798 Длина файла 3.13 мин
# 1043/9798 Длина файла 1.92 мин
# 1044/9798 Длина файла 1.07 мин
# 1045/9798 Длина файла 1.05 мин
# 1046/9798 Длина файла 1.98 мин
# 1047/9798 Длина файла 2.22 мин
# 1048/9798 Длина файла 1.60 мин
# 1049/9798 Длина файла 1.57 мин
# 1050/9798 Длина файла 2.93 мин
# 1051/9798 Длина файла 3.20 мин
# 1052/9798 Длина файла 2.33 мин
# 1053/9798 Длина файла 1.18 мин
# 1054/9798 Длина файла 1.82 мин
# 1055/9798 Длина файла 1.83 мин
# 1056/9798 Длина файла 1.04 мин
# 1057/9798 Длина файла 1.37 мин
# 1058/9798 Длина файла 2.47 мин
# 1059/9798 Длина файла 1.80 мин
# 1060/9798 Длина файла 0.92 мин
# 1061/9798 Длина файла 1.35 мин
# 1062/9798 Длина файла 2.20 мин
# 1063/9798 Длина файла 2.10 мин
# 1064/9798 Длина файла 1.12 мин
# 1065/9798 Длина файла 2.05 мин
# 1066/9798 Длина файла 3.08 мин
# 1067/9798 Длина файла 4.28 мин
# 1068/9798 Длина файла 3.10 мин
# 1069/9798 Длина файла 1.33 мин
# 1070/9798 Длина файла 1.88 мин
# 1071/9798 Длина файла 2.61 мин
# 1072/9798 Длина файла 0.83 мин
# 1073/9798 Длина файла 2.10 мин
# 1074/9798 Длина файла 2.95 мин
# 1075/9798 Длина файла 3.15 мин
# 1076/9798 Длина файла 2.14 мин
# 1077/9798 Длина файла 1.87 мин
# 1078/9798 Длина файла 2.90 мин
# 1079/9798 Длина файла 3.72 мин
# 1080/9798 Длина файла 3.29 мин
# 1081/9798 Длина файла 1.43 мин
# 1082/9798 Длина файла 2.72 мин
# 1083/9798 Длина файла 3.07 мин
# 1084/9798 Длина файла 2.26 мин
# 1085/9798 Длина файла 0.97 мин
# 1086/9798 Длина файла 2.03 мин
# 1087/9798 Длина файла 2.29 мин
# 1088/9798 Длина файла 1.45 мин
# 1089/9798 Длина файла 1.58 мин
# 1090/9798 Длина файла 2.52 мин
# 1091/9798 Длина файла 3.01 мин
# 1092/9798 Длина файла 1.78 мин
# 1093/9798 Длина файла 1.65 мин
# 1094/9798 Длина файла 3.28 мин
# 1095/9798 Длина файла 1.97 мин
# 1096/9798 Длина файла 0.88 мин
# 1097/9798 Длина файла 1.40 мин
# 1098/9798 Длина файла 2.32 мин
# 1099/9798 Длина файла 3.35 мин
# 1100/9798 Длина файла 2.13 мин
# 1101/9798 Длина файла 1.03 мин
# 1102/9798 Длина файла 2.48 мин
# 1103/9798 Длина файла 3.18 мин
# 1104/9798 Длина файла 1.77 мин
# 1105/9798 Длина файла 1.83 мин
# 1106/9798 Длина файла 4.50 мин
# 1107/9798 Длина файла 5.68 мин
# 1108/9798 Длина файла 3.21 мин
# 1109/9798 Длина файла 1.73 мин
# 1110/9798 Длина файла 4.50 мин
# 1111/9798 Длина файла 5.84 мин
# 1112/9798 Длина файла 4.21 мин
# 1113/9798 Длина файла 3.00 мин
# 1114/9798 Длина файла 5.72 мин
# 1115/9798 Длина файла 4.63 мин
# 1116/9798 Длина файла 3.28 мин
# 1117/9798 Длина файла 1.12 мин
# 1118/9798 Длина файла 3.45 мин
# 1119/9798 Длина файла 4.60 мин
# 1120/9798 Длина файла 5.57 мин
# 1121/9798 Длина файла 1.53 мин
# 1122/9798 Длина файла 4.37 мин
# 1123/9798 Длина файла 5.67 мин
# 1124/9798 Длина файла 4.60 мин
# 1125/9798 Длина файла 3.52 мин
# 1126/9798 Длина файла 5.55 мин
# 1127/9798 Длина файла 4.64 мин
# 1128/9798 Длина файла 2.63 мин
# 1129/9798 Длина файла 1.15 мин
# 1130/9798 Длина файла 3.13 мин
# 1131/9798 Длина файла 5.33 мин
# 1132/9798 Длина файла 5.00 мин
# 1133/9798 Длина файла 2.48 мин
# 1134/9798 Длина файла 5.48 мин
# 1135/9798 Длина файла 5.40 мин
# 1136/9798 Длина файла 4.26 мин
# 1137/9798 Длина файла 2.15 мин
# 1138/9798 Длина файла 3.97 мин
# 1139/9798 Длина файла 5.12 мин
# 1140/9798 Длина файла 5.07 мин
# 1141/9798 Длина файла 2.30 мин
# 1142/9798 Длина файла 3.87 мин
# 1143/9798 Длина файла 5.52 мин
# 1144/9798 Длина файла 4.70 мин
# 1145/9798 Длина файла 1.43 мин
# 1146/9798 Длина файла 3.27 мин
# 1147/9798 Длина файла 4.98 мин
# 1148/9798 Длина файла 5.71 мин
# 1149/9798 Длина файла 1.35 мин
# 1150/9798 Длина файла 3.75 мин
# 1151/9798 Длина файла 4.75 мин
# 1152/9798 Длина файла 6.16 мин
# 1153/9798 Длина файла 2.10 мин
# 1154/9798 Длина файла 6.03 мин
# 1155/9798 Длина файла 4.18 мин
# 1156/9798 Длина файла 2.83 мин
# 1157/9798 Длина файла 2.00 мин
# 1158/9798 Длина файла 4.28 мин
# 1159/9798 Длина файла 5.72 мин
# 1160/9798 Длина файла 4.58 мин
# 1161/9798 Длина файла 2.88 мин
# 1162/9798 Длина файла 5.40 мин
# 1163/9798 Длина файла 5.53 мин
# 1164/9798 Длина файла 4.17 мин
# 1165/9798 Длина файла 1.33 мин
# 1166/9798 Длина файла 3.28 мин
# 1167/9798 Длина файла 4.42 мин
# 1168/9798 Длина файла 6.21 мин
# 1169/9798 Длина файла 2.05 мин
# 1170/9798 Длина файла 3.65 мин
# 1171/9798 Длина файла 5.63 мин
# 1172/9798 Длина файла 5.23 мин
# 1173/9798 Длина файла 2.70 мин
# 1174/9798 Длина файла 5.33 мин
# 1175/9798 Длина файла 5.83 мин
# 1176/9798 Длина файла 3.08 мин
# 1177/9798 Длина файла 2.65 мин
# 1178/9798 Длина файла 4.05 мин
# 1179/9798 Длина файла 6.33 мин
# 1180/9798 Длина файла 4.22 мин
# 1181/9798 Длина файла 3.15 мин
# 1182/9798 Длина файла 5.72 мин
# 1183/9798 Длина файла 5.03 мин
# 1184/9798 Длина файла 3.61 мин
# 1185/9798 Длина файла 2.70 мин
# 1186/9798 Длина файла 5.52 мин
# 1187/9798 Длина файла 5.26 мин
# 1188/9798 Длина файла 3.23 мин
# 1189/9798 Длина файла 5.50 мин
# 1190/9798 Длина файла 4.83 мин
# 1191/9798 Длина файла 3.17 мин
# 1192/9798 Длина файла 1.58 мин
# 1193/9798 Длина файла 2.38 мин
# 1194/9798 Длина файла 3.30 мин
# 1195/9798 Длина файла 6.92 мин
# 1196/9798 Длина файла 2.07 мин
# 1197/9798 Длина файла 3.90 мин
# 1198/9798 Длина файла 4.93 мин
# 1199/9798 Длина файла 5.23 мин
# 1200/9798 Длина файла 2.08 мин
# 1201/9798 Длина файла 2.68 мин
# 1202/9798 Длина файла 7.53 мин
# 1203/9798 Длина файла 2.03 мин
# 1204/9798 Длина файла 4.82 мин
# 1205/9798 Длина файла 5.46 мин
# 1206/9798 Длина файла 3.46 мин
# 1207/9798 Длина файла 1.40 мин
# 1208/9798 Длина файла 2.50 мин
# 1209/9798 Длина файла 3.55 мин
# 1210/9798 Длина файла 1.25 мин
# 1211/9798 Длина файла 2.45 мин
# 1212/9798 Длина файла 3.63 мин
# 1213/9798 Длина файла 3.10 мин
# 1214/9798 Длина файла 4.08 мин
# 1215/9798 Длина файла 5.82 мин
# 1216/9798 Длина файла 4.48 мин
# 1217/9798 Длина файла 2.27 мин
# 1218/9798 Длина файла 3.18 мин
# 1219/9798 Длина файла 5.00 мин
# 1220/9798 Длина файла 5.22 мин
# 1221/9798 Длина файла 1.87 мин
# 1222/9798 Длина файла 3.60 мин
# 1223/9798 Длина файла 6.00 мин
# 1224/9798 Длина файла 4.35 мин
# 1225/9798 Длина файла 2.67 мин
# 1226/9798 Длина файла 3.95 мин
# 1227/9798 Длина файла 5.05 мин
# 1228/9798 Длина файла 5.26 мин
# 1229/9798 Длина файла 2.90 мин
# 1230/9798 Длина файла 6.15 мин
# 1231/9798 Длина файла 6.17 мин
# 1232/9798 Длина файла 4.69 мин
# 1233/9798 Длина файла 1.88 мин
# 1234/9798 Длина файла 4.60 мин
# 1235/9798 Длина файла 5.80 мин
# 1236/9798 Длина файла 4.82 мин
# 1237/9798 Длина файла 2.00 мин
# 1238/9798 Длина файла 4.05 мин
# 1239/9798 Длина файла 4.88 мин
# 1240/9798 Длина файла 5.39 мин
# 1241/9798 Длина файла 1.87 мин
# 1242/9798 Длина файла 5.72 мин
# 1243/9798 Длина файла 4.89 мин
# 1244/9798 Длина файла 3.71 мин
# 1245/9798 Длина файла 2.72 мин
# 1246/9798 Длина файла 4.33 мин
# 1247/9798 Длина файла 6.05 мин
# 1248/9798 Длина файла 4.40 мин
# 1249/9798 Длина файла 1.95 мин
# 1250/9798 Длина файла 5.02 мин
# 1251/9798 Длина файла 5.68 мин
# 1252/9798 Длина файла 4.69 мин
# 1253/9798 Длина файла 2.22 мин
# 1254/9798 Длина файла 4.12 мин
# 1255/9798 Длина файла 5.32 мин
# 1256/9798 Длина файла 5.00 мин
# 1257/9798 Длина файла 1.45 мин
# 1258/9798 Длина файла 6.27 мин
# 1259/9798 Длина файла 4.62 мин
# 1260/9798 Длина файла 2.39 мин
# 1261/9798 Длина файла 3.03 мин
# 1262/9798 Длина файла 6.85 мин
# 1263/9798 Длина файла 4.26 мин
# 1264/9798 Длина файла 2.52 мин
# 1265/9798 Длина файла 2.50 мин
# 1266/9798 Длина файла 7.23 мин
# 1267/9798 Длина файла 4.00 мин
# 1268/9798 Длина файла 1.03 мин
# 1269/9798 Длина файла 1.90 мин
# 1270/9798 Длина файла 5.18 мин
# 1271/9798 Длина файла 5.55 мин
# 1272/9798 Длина файла 3.78 мин
# 1273/9798 Длина файла 1.90 мин
# 1274/9798 Длина файла 4.17 мин
# 1275/9798 Длина файла 6.73 мин
# 1276/9798 Длина файла 3.58 мин
# 1277/9798 Длина файла 1.92 мин
# 1278/9798 Длина файла 5.93 мин
# 1279/9798 Длина файла 4.90 мин
# 1280/9798 Длина файла 3.15 мин
# 1281/9798 Длина файла 2.62 мин
# 1282/9798 Длина файла 5.53 мин
# 1283/9798 Длина файла 5.56 мин
# 1284/9798 Длина файла 2.47 мин
# 1285/9798 Длина файла 2.07 мин
# 1286/9798 Длина файла 4.90 мин
# 1287/9798 Длина файла 6.12 мин
# 1288/9798 Длина файла 3.89 мин
# 1289/9798 Длина файла 2.92 мин
# 1290/9798 Длина файла 5.50 мин
# 1291/9798 Длина файла 6.02 мин
# 1292/9798 Длина файла 3.54 мин
# 1293/9798 Длина файла 3.18 мин
# 1294/9798 Длина файла 5.50 мин
# 1295/9798 Длина файла 5.33 мин
# 1296/9798 Длина файла 2.56 мин
# 1297/9798 Длина файла 1.97 мин
# 1298/9798 Длина файла 4.22 мин
# 1299/9798 Длина файла 6.22 мин
# 1300/9798 Длина файла 4.68 мин
# 1301/9798 Длина файла 2.50 мин
# 1302/9798 Длина файла 6.22 мин
# 1303/9798 Длина файла 4.84 мин
# 1304/9798 Длина файла 2.64 мин
# 1305/9798 Длина файла 3.18 мин
# 1306/9798 Длина файла 6.02 мин
# 1307/9798 Длина файла 5.11 мин
# 1308/9798 Длина файла 3.13 мин
# 1309/9798 Длина файла 2.62 мин
# 1310/9798 Длина файла 6.15 мин
# 1311/9798 Длина файла 4.81 мин
# 1312/9798 Длина файла 2.92 мин
# 1313/9798 Длина файла 1.82 мин
# 1314/9798 Длина файла 4.98 мин
# 1315/9798 Длина файла 5.30 мин
# 1316/9798 Длина файла 4.07 мин
# 1317/9798 Длина файла 1.32 мин
# 1318/9798 Длина файла 3.50 мин
# 1319/9798 Длина файла 5.40 мин
# 1320/9798 Длина файла 5.29 мин
# 1321/9798 Длина файла 2.72 мин
# 1322/9798 Длина файла 3.87 мин
# 1323/9798 Длина файла 5.48 мин
# 1324/9798 Длина файла 4.69 мин
# 1325/9798 Длина файла 1.53 мин
# 1326/9798 Длина файла 5.98 мин
# 1327/9798 Длина файла 4.32 мин
# 1328/9798 Длина файла 2.62 мин
# 1329/9798 Длина файла 2.17 мин
# 1330/9798 Длина файла 6.18 мин
# 1331/9798 Длина файла 4.27 мин
# 1332/9798 Длина файла 2.95 мин
# 1333/9798 Длина файла 3.93 мин
# 1334/9798 Длина файла 5.15 мин
# 1335/9798 Длина файла 5.29 мин
# 1336/9798 Длина файла 1.00 мин
# 1337/9798 Длина файла 2.48 мин
# 1338/9798 Длина файла 4.03 мин
# 1339/9798 Длина файла 6.08 мин
# 1340/9798 Длина файла 1.25 мин
# 1341/9798 Длина файла 3.92 мин
# 1342/9798 Длина файла 5.60 мин
# 1343/9798 Длина файла 4.72 мин
# 1344/9798 Длина файла 1.95 мин
# 1345/9798 Длина файла 5.97 мин
# 1346/9798 Длина файла 4.35 мин
# 1347/9798 Длина файла 3.07 мин
# 1348/9798 Длина файла 0.98 мин
# 1349/9798 Длина файла 3.85 мин
# 1350/9798 Длина файла 5.73 мин
# 1351/9798 Длина файла 4.69 мин
# 1352/9798 Длина файла 1.38 мин
# 1353/9798 Длина файла 3.38 мин
# 1354/9798 Длина файла 4.55 мин
# 1355/9798 Длина файла 5.98 мин
# 1356/9798 Длина файла 1.32 мин
# 1357/9798 Длина файла 4.07 мин
# 1358/9798 Длина файла 5.52 мин
# 1359/9798 Длина файла 4.79 мин
# 1360/9798 Длина файла 1.87 мин
# 1361/9798 Длина файла 5.70 мин
# 1362/9798 Длина файла 5.32 мин
# 1363/9798 Длина файла 2.73 мин
# 1364/9798 Длина файла 1.83 мин
# 1365/9798 Длина файла 3.25 мин
# 1366/9798 Длина файла 4.53 мин
# 1367/9798 Длина файла 5.60 мин
# 1368/9798 Длина файла 1.65 мин
# 1369/9798 Длина файла 5.18 мин
# 1370/9798 Длина файла 5.07 мин
# 1371/9798 Длина файла 3.72 мин
# 1372/9798 Длина файла 1.27 мин
# 1373/9798 Длина файла 3.55 мин
# 1374/9798 Длина файла 4.45 мин
# 1375/9798 Длина файла 6.19 мин
# 1376/9798 Длина файла 1.83 мин
# 1377/9798 Длина файла 2.92 мин
# 1378/9798 Длина файла 4.22 мин
# 1379/9798 Длина файла 5.88 мин
# 1380/9798 Длина файла 2.75 мин
# 1381/9798 Длина файла 6.50 мин
# 1382/9798 Длина файла 4.41 мин
# 1383/9798 Длина файла 3.16 мин
# 1384/9798 Длина файла 1.65 мин
# 1385/9798 Длина файла 3.28 мин
# 1386/9798 Длина файла 4.92 мин
# 1387/9798 Длина файла 5.52 мин
# 1388/9798 Длина файла 2.57 мин
# 1389/9798 Длина файла 5.07 мин
# 1390/9798 Длина файла 6.35 мин
# 1391/9798 Длина файла 4.31 мин
# 1392/9798 Длина файла 1.48 мин
# 1393/9798 Длина файла 5.63 мин
# 1394/9798 Длина файла 5.70 мин
# 1395/9798 Длина файла 4.31 мин
# 1396/9798 Длина файла 3.10 мин
# 1397/9798 Длина файла 5.16 мин
# 1398/9798 Длина файла 2.96 мин
# 1399/9798 Длина файла 2.93 мин
# 1400/9798 Длина файла 5.88 мин
# 1401/9798 Длина файла 5.80 мин
# 1402/9798 Длина файла 3.48 мин
# 1403/9798 Длина файла 3.13 мин
# 1404/9798 Длина файла 4.17 мин
# 1405/9798 Длина файла 6.03 мин
# 1406/9798 Длина файла 5.47 мин
# 1407/9798 Длина файла 2.13 мин
# 1408/9798 Длина файла 4.18 мин
# 1409/9798 Длина файла 7.03 мин
# 1410/9798 Длина файла 4.87 мин
# 1411/9798 Длина файла 1.63 мин
# 1412/9798 Длина файла 4.55 мин
# 1413/9798 Длина файла 7.13 мин
# 1414/9798 Длина файла 4.34 мин
# 1415/9798 Длина файла 2.63 мин
# 1416/9798 Длина файла 3.80 мин
# 1417/9798 Длина файла 6.20 мин
# 1418/9798 Длина файла 4.87 мин
# 1419/9798 Длина файла 1.63 мин
# 1420/9798 Длина файла 3.32 мин
# 1421/9798 Длина файла 5.87 мин
# 1422/9798 Длина файла 5.79 мин
# 1423/9798 Длина файла 1.87 мин
# 1424/9798 Длина файла 3.20 мин
# 1425/9798 Длина файла 5.52 мин
# 1426/9798 Длина файла 5.97 мин
# 1427/9798 Длина файла 2.23 мин
# 1428/9798 Длина файла 4.05 мин
# 1429/9798 Длина файла 6.29 мин
# 1430/9798 Длина файла 3.99 мин
# 1431/9798 Длина файла 2.42 мин
# 1432/9798 Длина файла 3.77 мин
# 1433/9798 Длина файла 5.32 мин
# 1434/9798 Длина файла 5.11 мин
# 1435/9798 Длина файла 3.48 мин
# 1436/9798 Длина файла 4.88 мин
# 1437/9798 Длина файла 5.34 мин
# 1438/9798 Длина файла 4.17 мин
# 1439/9798 Длина файла 1.92 мин
# 1440/9798 Длина файла 3.78 мин
# 1441/9798 Длина файла 4.88 мин
# 1442/9798 Длина файла 5.35 мин
# 1443/9798 Длина файла 1.90 мин
# 1444/9798 Длина файла 2.78 мин
# 1445/9798 Длина файла 3.65 мин
# 1446/9798 Длина файла 6.79 мин
# 1447/9798 Длина файла 1.75 мин
# 1448/9798 Длина файла 2.88 мин
# 1449/9798 Длина файла 4.62 мин
# 1450/9798 Длина файла 5.63 мин
# 1451/9798 Длина файла 1.95 мин
# 1452/9798 Длина файла 3.97 мин
# 1453/9798 Длина файла 5.63 мин
# 1454/9798 Длина файла 4.72 мин
# 1455/9798 Длина файла 1.63 мин
# 1456/9798 Длина файла 3.10 мин
# 1457/9798 Длина файла 4.10 мин
# 1458/9798 Длина файла 6.26 мин
# 1459/9798 Длина файла 1.67 мин
# 1460/9798 Длина файла 2.97 мин
# 1461/9798 Длина файла 4.48 мин
# 1462/9798 Длина файла 5.70 мин
# 1463/9798 Длина файла 1.72 мин
# 1464/9798 Длина файла 2.50 мин
# 1465/9798 Длина файла 3.65 мин
# 1466/9798 Длина файла 6.57 мин
# 1467/9798 Длина файла 3.47 мин
# 1468/9798 Длина файла 6.53 мин
# 1469/9798 Длина файла 6.74 мин
# 1470/9798 Длина файла 1.68 мин
# 1471/9798 Длина файла 1.63 мин
# 1472/9798 Длина файла 3.30 мин
# 1473/9798 Длина файла 4.23 мин
# 1474/9798 Длина файла 6.05 мин
# 1475/9798 Длина файла 2.02 мин
# 1476/9798 Длина файла 3.63 мин
# 1477/9798 Длина файла 5.17 мин
# 1478/9798 Длина файла 5.10 мин
# 1479/9798 Длина файла 2.45 мин
# 1480/9798 Длина файла 4.23 мин
# 1481/9798 Длина файла 5.85 мин
# 1482/9798 Длина файла 4.57 мин
# 1483/9798 Длина файла 2.75 мин
# 1484/9798 Длина файла 6.20 мин
# 1485/9798 Длина файла 4.21 мин
# 1486/9798 Длина файла 2.36 мин
# 1487/9798 Длина файла 2.45 мин
# 1488/9798 Длина файла 5.13 мин
# 1489/9798 Длина файла 5.39 мин
# 1490/9798 Длина файла 3.17 мин
# 1491/9798 Длина файла 1.98 мин
# 1492/9798 Длина файла 3.50 мин
# 1493/9798 Длина файла 5.83 мин
# 1494/9798 Длина файла 4.74 мин
# 1495/9798 Длина файла 2.08 мин
# 1496/9798 Длина файла 4.08 мин
# 1497/9798 Длина файла 5.62 мин
# 1498/9798 Длина файла 4.74 мин
# 1499/9798 Длина файла 6.45 мин
# 1500/9798 Длина файла 5.04 мин
# 1501/9798 Длина файла 3.45 мин
# 1502/9798 Длина файла 2.02 мин
# 1503/9798 Длина файла 3.52 мин
# 1504/9798 Длина файла 4.65 мин
# 1505/9798 Длина файла 5.62 мин
# 1506/9798 Длина файла 1.65 мин
# 1507/9798 Длина файла 3.53 мин
# 1508/9798 Длина файла 4.43 мин
# 1509/9798 Длина файла 5.71 мин
# 1510/9798 Длина файла 1.43 мин
# 1511/9798 Длина файла 3.22 мин
# 1512/9798 Длина файла 4.05 мин
# 1513/9798 Длина файла 6.23 мин
# 1514/9798 Длина файла 1.32 мин
# 1515/9798 Длина файла 5.47 мин
# 1516/9798 Длина файла 4.63 мин
# 1517/9798 Длина файла 1.73 мин
# 1518/9798 Длина файла 3.28 мин
# 1519/9798 Длина файла 6.81 мин
# 1520/9798 Длина файла 3.26 мин
# 1521/9798 Длина файла 1.82 мин
# 1522/9798 Длина файла 3.87 мин
# 1523/9798 Длина файла 4.97 мин
# 1524/9798 Длина файла 5.22 мин
# 1525/9798 Длина файла 1.58 мин
# 1526/9798 Длина файла 3.15 мин
# 1527/9798 Длина файла 4.02 мин
# 1528/9798 Длина файла 6.13 мин
# 1529/9798 Длина файла 1.58 мин
# 1530/9798 Длина файла 3.02 мин
# 1531/9798 Длина файла 4.23 мин
# 1532/9798 Длина файла 5.88 мин
# 1533/9798 Длина файла 1.63 мин
# 1534/9798 Длина файла 3.00 мин
# 1535/9798 Длина файла 4.00 мин
# 1536/9798 Длина файла 6.16 мин
# 1537/9798 Длина файла 1.82 мин
# 1538/9798 Длина файла 2.80 мин
# 1539/9798 Длина файла 3.75 мин
# 1540/9798 Длина файла 6.52 мин
# 1541/9798 Длина файла 2.47 мин
# 1542/9798 Длина файла 4.18 мин
# 1543/9798 Длина файла 6.00 мин
# 1544/9798 Длина файла 4.04 мин
# 1545/9798 Длина файла 1.62 мин
# 1546/9798 Длина файла 2.48 мин
# 1547/9798 Длина файла 3.70 мин
# 1548/9798 Длина файла 6.49 мин
# 1549/9798 Длина файла 2.43 мин
# 1550/9798 Длина файла 3.25 мин
# 1551/9798 Длина файла 4.08 мин
# 1552/9798 Длина файла 6.13 мин
# 1553/9798 Длина файла 1.52 мин
# 1554/9798 Длина файла 2.38 мин
# 1555/9798 Длина файла 3.05 мин
# 1556/9798 Длина файла 7.08 мин
# 1557/9798 Длина файла 1.63 мин
# 1558/9798 Длина файла 2.45 мин
# 1559/9798 Длина файла 4.07 мин
# 1560/9798 Длина файла 6.05 мин
# 1561/9798 Длина файла 1.38 мин
# 1562/9798 Длина файла 3.98 мин
# 1563/9798 Длина файла 4.68 мин
# 1564/9798 Длина файла 5.51 мин
# 1565/9798 Длина файла 1.77 мин
# 1566/9798 Длина файла 3.57 мин
# 1567/9798 Длина файла 4.80 мин
# 1568/9798 Длина файла 5.35 мин
# 1569/9798 Длина файла 1.85 мин
# 1570/9798 Длина файла 2.88 мин
# 1571/9798 Длина файла 3.68 мин
# 1572/9798 Длина файла 6.50 мин
# 1573/9798 Длина файла 1.97 мин
# 1574/9798 Длина файла 3.37 мин
# 1575/9798 Длина файла 4.95 мин
# 1576/9798 Длина файла 5.24 мин
# 1577/9798 Длина файла 1.48 мин
# 1578/9798 Длина файла 2.72 мин
# 1579/9798 Длина файла 3.48 мин
# 1580/9798 Длина файла 2.55 мин
# ...
# 9309/9798 Длина файла 5.73 мин
# 9310/9798 Длина файла 4.50 мин
# 9311/9798 Длина файла 2.12 мин
# 9312/9798 Длина файла 5.27 мин
# 9313/9798 Длина файла 5.39 мин
# 9314/9798 Длина файла 2.66 мин
# 9315/9798 Длина файла 1.50 мин
# 9316/9798 Длина файла 3.90 мин
# 9317/9798 Длина файла 4.98 мин
# 9318/9798 Длина файла 5.27 мин
# 9319/9798 Длина файла 1.35 мин
# 9320/9798 Длина файла 2.65 мин
# 9321/9798 Длина файла 4.12 мин
# 9322/9798 Длина файла 6.01 мин
# 9323/9798 Длина файла 1.47 мин
# 9324/9798 Длина файла 2.65 мин
# 9325/9798 Длина файла 4.75 мин
# 9326/9798 Длина файла 6.01 мин
# 9327/9798 Длина файла 1.08 мин
# 9328/9798 Длина файла 2.15 мин
# 9329/9798 Длина файла 3.10 мин
# 9330/9798 Длина файла 7.01 мин
# 9331/9798 Длина файла 2.17 мин
# 9332/9798 Длина файла 5.95 мин
# 9333/9798 Длина файла 4.37 мин
# 9334/9798 Длина файла 3.13 мин
# 9335/9798 Длина файла 4.40 мин
# 9336/9798 Длина файла 5.68 мин
# 9337/9798 Длина файла 4.35 мин
# 9338/9798 Длина файла 2.17 мин
# 9339/9798 Длина файла 3.20 мин
# 9340/9798 Длина файла 4.13 мин
# 9341/9798 Длина файла 6.00 мин
# 9342/9798 Длина файла 2.37 мин
# 9343/9798 Длина файла 3.57 мин
# 9344/9798 Длина файла 4.82 мин
# 9345/9798 Длина файла 5.26 мин
# 9346/9798 Длина файла 1.38 мин
# 9347/9798 Длина файла 2.22 мин
# 9348/9798 Длина файла 3.23 мин
# 9349/9798 Длина файла 6.86 мин
# 9350/9798 Длина файла 2.07 мин
# 9351/9798 Длина файла 4.02 мин
# 9352/9798 Длина файла 5.73 мин
# 9353/9798 Длина файла 4.38 мин
# 9354/9798 Длина файла 2.53 мин
# 9355/9798 Длина файла 2.32 мин
# 9356/9798 Длина файла 2.32 мин
# 9357/9798 Длина файла 4.58 мин
# 9358/9798 Длина файла 5.51 мин
# 9359/9798 Длина файла 2.28 мин
# 9360/9798 Длина файла 4.55 мин
# 9361/9798 Длина файла 3.66 мин
# 9362/9798 Длина файла 2.47 мин
# 9363/9798 Длина файла 1.68 мин
# 9364/9798 Длина файла 5.20 мин
# 9365/9798 Длина файла 5.32 мин
# 9366/9798 Длина файла 3.29 мин
# 9367/9798 Длина файла 1.32 мин
# 9368/9798 Длина файла 4.25 мин
# 9369/9798 Длина файла 3.58 мин
# 9370/9798 Длина файла 2.01 мин
# 9371/9798 Длина файла 1.98 мин
# 9372/9798 Длина файла 4.47 мин
# 9373/9798 Длина файла 4.08 мин
# 9374/9798 Длина файла 2.60 мин
# 9375/9798 Длина файла 1.38 мин
# 9376/9798 Длина файла 3.87 мин
# 9377/9798 Длина файла 4.02 мин
# 9378/9798 Длина файла 2.32 мин
# 9379/9798 Длина файла 1.73 мин
# 9380/9798 Длина файла 4.48 мин
# 9381/9798 Длина файла 3.62 мин
# 9382/9798 Длина файла 2.57 мин
# 9383/9798 Длина файла 2.33 мин
# 9384/9798 Длина файла 4.57 мин
# 9385/9798 Длина файла 3.65 мин
# 9386/9798 Длина файла 2.06 мин
# 9387/9798 Длина файла 1.22 мин
# 9388/9798 Длина файла 4.10 мин
# 9389/9798 Длина файла 3.54 мин
# 9390/9798 Длина файла 2.43 мин
# 9391/9798 Длина файла 2.60 мин
# 9392/9798 Длина файла 4.50 мин
# 9393/9798 Длина файла 5.78 мин
# 9394/9798 Длина файла 3.85 мин
# 9395/9798 Длина файла 2.00 мин
# 9396/9798 Длина файла 4.67 мин
# 9397/9798 Длина файла 5.60 мин
# 9398/9798 Длина файла 4.63 мин
# 9399/9798 Длина файла 1.67 мин
# 9400/9798 Длина файла 4.77 мин
# 9401/9798 Длина файла 5.53 мин
# 9402/9798 Длина файла 4.33 мин
# 9403/9798 Длина файла 1.70 мин
# 9404/9798 Длина файла 4.13 мин
# 9405/9798 Длина файла 5.63 мин
# 9406/9798 Длина файла 4.46 мин
# 9407/9798 Длина файла 3.15 мин
# 9408/9798 Длина файла 4.78 мин
# 9409/9798 Длина файла 5.45 мин
# 9410/9798 Длина файла 3.43 мин
# 9411/9798 Длина файла 1.88 мин
# 9412/9798 Длина файла 4.15 мин
# 9413/9798 Длина файла 6.00 мин
# 9414/9798 Длина файла 4.03 мин
# 9415/9798 Длина файла 1.85 мин
# 9416/9798 Длина файла 4.23 мин
# 9417/9798 Длина файла 5.95 мин
# 9418/9798 Длина файла 4.03 мин
# 9419/9798 Длина файла 1.87 мин
# 9420/9798 Длина файла 4.92 мин
# 9421/9798 Длина файла 5.15 мин
# 9422/9798 Длина файла 3.71 мин
# 9423/9798 Длина файла 1.88 мин
# 9424/9798 Длина файла 4.00 мин
# 9425/9798 Длина файла 5.47 мин
# 9426/9798 Длина файла 4.66 мин
# 9427/9798 Длина файла 3.25 мин
# 9428/9798 Длина файла 4.77 мин
# 9429/9798 Длина файла 5.42 мин
# 9430/9798 Длина файла 3.17 мин
# 9431/9798 Длина файла 2.03 мин
# 9432/9798 Длина файла 5.60 мин
# 9433/9798 Длина файла 4.57 мин
# 9434/9798 Длина файла 3.20 мин
# 9435/9798 Длина файла 1.80 мин
# 9436/9798 Длина файла 3.72 мин
# 9437/9798 Длина файла 4.88 мин
# 9438/9798 Длина файла 5.23 мин
# 9439/9798 Длина файла 2.58 мин
# 9440/9798 Длина файла 5.69 мин
# 9441/9798 Длина файла 3.66 мин
# 9442/9798 Длина файла 2.02 мин
# 9443/9798 Длина файла 3.52 мин
# 9444/9798 Длина файла 5.02 мин
# 9445/9798 Длина файла 5.18 мин
# 9446/9798 Длина файла 3.23 мин
# 9447/9798 Длина файла 5.43 мин
# 9448/9798 Длина файла 4.82 мин
# 9449/9798 Длина файла 2.90 мин
# 9450/9798 Длина файла 2.20 мин
# 9451/9798 Длина файла 4.17 мин
# 9452/9798 Длина файла 5.90 мин
# 9453/9798 Длина файла 3.16 мин
# 9454/9798 Длина файла 2.18 мин
# 9455/9798 Длина файла 4.55 мин
# 9456/9798 Длина файла 5.63 мин
# 9457/9798 Длина файла 4.06 мин
# 9458/9798 Длина файла 3.13 мин
# 9459/9798 Длина файла 5.35 мин
# 9460/9798 Длина файла 5.09 мин
# 9461/9798 Длина файла 3.21 мин
# 9462/9798 Длина файла 1.92 мин
# 9463/9798 Длина файла 4.82 мин
# 9464/9798 Длина файла 3.52 мин
# 9465/9798 Длина файла 2.32 мин
# 9466/9798 Длина файла 3.65 мин
# 9467/9798 Длина файла 5.12 мин
# 9468/9798 Длина файла 5.03 мин
# 9469/9798 Длина файла 2.43 мин
# 9470/9798 Длина файла 4.07 мин
# 9471/9798 Длина файла 6.07 мин
# 9472/9798 Длина файла 4.54 мин
# 9473/9798 Длина файла 2.88 мин
# 9474/9798 Длина файла 5.10 мин
# 9475/9798 Длина файла 5.08 мин
# 9476/9798 Длина файла 3.10 мин
# 9477/9798 Длина файла 2.77 мин
# 9478/9798 Длина файла 4.85 мин
# 9479/9798 Длина файла 3.53 мин
# 9480/9798 Длина файла 2.30 мин
# 9481/9798 Длина файла 4.05 мин
# 9482/9798 Длина файла 6.88 мин
# 9483/9798 Длина файла 4.22 мин
# 9484/9798 Длина файла 4.27 мин
# 9485/9798 Длина файла 6.33 мин
# 9486/9798 Длина файла 4.87 мин
# 9487/9798 Длина файла 3.23 мин
# 9488/9798 Длина файла 4.38 мин
# 9489/9798 Длина файла 4.60 мин
# 9490/9798 Длина файла 2.15 мин
# 9491/9798 Длина файла 3.33 мин
# 9492/9798 Длина файла 4.90 мин
# 9493/9798 Длина файла 6.00 мин
# 9494/9798 Длина файла 2.35 мин
# 9495/9798 Длина файла 4.00 мин
# 9496/9798 Длина файла 6.08 мин
# 9497/9798 Длина файла 4.06 мин
# 9498/9798 Длина файла 2.68 мин
# 9499/9798 Длина файла 5.17 мин
# 9500/9798 Длина файла 5.74 мин
# 9501/9798 Длина файла 2.94 мин
# 9502/9798 Длина файла 2.68 мин
# 9503/9798 Длина файла 5.80 мин
# 9504/9798 Длина файла 4.56 мин
# 9505/9798 Длина файла 3.36 мин
# 9506/9798 Длина файла 2.30 мин
# 9507/9798 Длина файла 4.32 мин
# 9508/9798 Длина файла 5.62 мин
# 9509/9798 Длина файла 4.58 мин
# 9510/9798 Длина файла 3.18 мин
# 9511/9798 Длина файла 8.42 мин
# 9512/9798 Длина файла 3.53 мин
# 9513/9798 Длина файла 2.48 мин
# 9514/9798 Длина файла 2.83 мин
# 9515/9798 Длина файла 5.77 мин
# 9516/9798 Длина файла 4.44 мин
# 9517/9798 Длина файла 2.69 мин
# 9518/9798 Длина файла 1.23 мин
# 9519/9798 Длина файла 2.02 мин
# 9520/9798 Длина файла 2.18 мин
# 9521/9798 Длина файла 1.36 мин
# 9522/9798 Длина файла 1.58 мин
# 9523/9798 Длина файла 2.58 мин
# 9524/9798 Длина файла 2.65 мин
# 9525/9798 Длина файла 1.54 мин
# 9526/9798 Длина файла 1.97 мин
# 9527/9798 Длина файла 3.70 мин
# 9528/9798 Длина файла 4.07 мин
# 9529/9798 Длина файла 2.38 мин
# 9530/9798 Длина файла 1.25 мин
# 9531/9798 Длина файла 2.43 мин
# 9532/9798 Длина файла 2.58 мин
# 9533/9798 Длина файла 1.56 мин
# 9534/9798 Длина файла 1.47 мин
# 9535/9798 Длина файла 2.35 мин
# 9536/9798 Длина файла 2.32 мин
# 9537/9798 Длина файла 1.44 мин
# 9538/9798 Длина файла 1.17 мин
# 9539/9798 Длина файла 2.52 мин
# 9540/9798 Длина файла 2.68 мин
# 9541/9798 Длина файла 1.92 мин
# 9542/9798 Длина файла 1.72 мин
# 9543/9798 Длина файла 3.07 мин
# 9544/9798 Длина файла 2.92 мин
# 9545/9798 Длина файла 1.70 мин
# 9546/9798 Длина файла 1.47 мин
# 9547/9798 Длина файла 2.57 мин
# 9548/9798 Длина файла 2.86 мин
# 9549/9798 Длина файла 1.74 мин
# 9550/9798 Длина файла 2.37 мин
# 9551/9798 Длина файла 4.15 мин
# 9552/9798 Длина файла 3.13 мин
# 9553/9798 Длина файла 2.03 мин
# 9554/9798 Длина файла 2.02 мин
# 9555/9798 Длина файла 3.43 мин
# 9556/9798 Длина файла 3.01 мин
# 9557/9798 Длина файла 2.19 мин
# 9558/9798 Длина файла 1.23 мин
# 9559/9798 Длина файла 1.88 мин
# 9560/9798 Длина файла 1.91 мин
# 9561/9798 Длина файла 1.07 мин
# 9562/9798 Длина файла 1.05 мин
# 9563/9798 Длина файла 2.27 мин
# 9564/9798 Длина файла 2.20 мин
# 9565/9798 Длина файла 1.47 мин
# 9566/9798 Длина файла 1.68 мин
# 9567/9798 Длина файла 3.90 мин
# 9568/9798 Длина файла 4.88 мин
# 9569/9798 Длина файла 5.50 мин
# 9570/9798 Длина файла 5.85 мин
# 9571/9798 Длина файла 2.83 мин
# 9572/9798 Длина файла 7.63 мин
# 9573/9798 Длина файла 2.91 мин
# 9574/9798 Длина файла 1.64 мин
# 9575/9798 Длина файла 2.55 мин
# 9576/9798 Длина файла 4.15 мин
# 9577/9798 Длина файла 5.87 мин
# 9578/9798 Длина файла 4.23 мин
# 9579/9798 Длина файла 2.48 мин
# 9580/9798 Длина файла 4.47 мин
# 9581/9798 Длина файла 6.07 мин
# 9582/9798 Длина файла 3.52 мин
# 9583/9798 Длина файла 3.55 мин
# 9584/9798 Длина файла 5.22 мин
# 9585/9798 Длина файла 4.95 мин
# 9586/9798 Длина файла 2.82 мин
# 9587/9798 Длина файла 2.15 мин
# 9588/9798 Длина файла 5.60 мин
# 9589/9798 Длина файла 4.55 мин
# 9590/9798 Длина файла 2.95 мин
# 9591/9798 Длина файла 2.10 мин
# 9592/9798 Длина файла 4.20 мин
# 9593/9798 Длина файла 5.82 мин
# 9594/9798 Длина файла 4.42 мин
# 9595/9798 Длина файла 2.25 мин
# 9596/9798 Длина файла 5.07 мин
# 9597/9798 Длина файла 5.20 мин
# 9598/9798 Длина файла 3.83 мин
# 9599/9798 Длина файла 2.68 мин
# 9600/9798 Длина файла 4.52 мин
# 9601/9798 Длина файла 6.01 мин
# 9602/9798 Длина файла 4.22 мин
# 9603/9798 Длина файла 1.78 мин
# 9604/9798 Длина файла 4.72 мин
# 9605/9798 Длина файла 5.43 мин
# 9606/9798 Длина файла 3.67 мин
# 9607/9798 Длина файла 1.53 мин
# 9608/9798 Длина файла 3.93 мин
# 9609/9798 Длина файла 5.23 мин
# 9610/9798 Длина файла 4.95 мин
# 9611/9798 Длина файла 2.62 мин
# 9612/9798 Длина файла 4.83 мин
# 9613/9798 Длина файла 5.31 мин
# 9614/9798 Длина файла 4.26 мин
# 9615/9798 Длина файла 2.72 мин
# 9616/9798 Длина файла 4.78 мин
# 9617/9798 Длина файла 5.57 мин
# 9618/9798 Длина файла 4.47 мин
# 9619/9798 Длина файла 2.82 мин
# 9620/9798 Длина файла 5.82 мин
# 9621/9798 Длина файла 6.22 мин
# 9622/9798 Длина файла 4.28 мин
# 9623/9798 Длина файла 1.98 мин
# 9624/9798 Длина файла 4.72 мин
# 9625/9798 Длина файла 5.50 мин
# 9626/9798 Длина файла 4.42 мин
# 9627/9798 Длина файла 2.10 мин
# 9628/9798 Длина файла 4.80 мин
# 9629/9798 Длина файла 5.77 мин
# 9630/9798 Длина файла 5.92 мин
# 9631/9798 Длина файла 2.65 мин
# 9632/9798 Длина файла 6.07 мин
# 9633/9798 Длина файла 5.77 мин
# 9634/9798 Длина файла 4.12 мин
# 9635/9798 Длина файла 1.52 мин
# 9636/9798 Длина файла 1.42 мин
# 9637/9798 Длина файла 1.42 мин
# 9638/9798 Длина файла 2.07 мин
# 9639/9798 Длина файла 7.47 мин
# 9640/9798 Длина файла 2.38 мин
# 9641/9798 Длина файла 4.10 мин
# 9642/9798 Длина файла 5.72 мин
# 9643/9798 Длина файла 4.79 мин
# 9644/9798 Длина файла 2.15 мин
# 9645/9798 Длина файла 5.77 мин
# 9646/9798 Длина файла 4.45 мин
# 9647/9798 Длина файла 2.05 мин
# 9648/9798 Длина файла 3.00 мин
# 9649/9798 Длина файла 5.70 мин
# 9650/9798 Длина файла 4.41 мин
# 9651/9798 Длина файла 3.05 мин
# 9652/9798 Длина файла 3.87 мин
# 9653/9798 Длина файла 6.42 мин
# 9654/9798 Длина файла 4.55 мин
# 9655/9798 Длина файла 1.86 мин
# 9656/9798 Длина файла 3.20 мин
# 9657/9798 Длина файла 5.10 мин
# 9658/9798 Длина файла 5.47 мин
# 9659/9798 Длина файла 3.27 мин
# 9660/9798 Длина файла 2.78 мин
# 9661/9798 Длина файла 6.00 мин
# 9662/9798 Длина файла 3.13 мин
# 9663/9798 Длина файла 1.63 мин
# 9664/9798 Длина файла 2.37 мин
# 9665/9798 Длина файла 4.37 мин
# 9666/9798 Длина файла 3.21 мин
# 9667/9798 Длина файла 1.99 мин
# 9668/9798 Длина файла 1.58 мин
# 9669/9798 Длина файла 4.33 мин
# 9670/9798 Длина файла 3.44 мин
# 9671/9798 Длина файла 1.99 мин
# 9672/9798 Длина файла 1.47 мин
# 9673/9798 Длина файла 4.15 мин
# 9674/9798 Длина файла 3.27 мин
# 9675/9798 Длина файла 1.64 мин
# 9676/9798 Длина файла 1.67 мин
# 9677/9798 Длина файла 4.22 мин
# 9678/9798 Длина файла 3.76 мин
# 9679/9798 Длина файла 2.41 мин
# 9680/9798 Длина файла 1.98 мин
# 9681/9798 Длина файла 4.40 мин
# 9682/9798 Длина файла 4.19 мин
# 9683/9798 Длина файла 2.46 мин
# 9684/9798 Длина файла 1.65 мин
# 9685/9798 Длина файла 4.53 мин
# 9686/9798 Длина файла 3.24 мин
# 9687/9798 Длина файла 2.26 мин
# 9688/9798 Длина файла 1.32 мин
# 9689/9798 Длина файла 4.17 мин
# 9690/9798 Длина файла 3.52 мин
# 9691/9798 Длина файла 2.76 мин
# 9692/9798 Длина файла 2.28 мин
# 9693/9798 Длина файла 5.30 мин
# 9694/9798 Длина файла 3.91 мин
# 9695/9798 Длина файла 2.44 мин
# 9696/9798 Длина файла 2.30 мин
# 9697/9798 Длина файла 5.90 мин
# 9698/9798 Длина файла 3.65 мин
# 9699/9798 Длина файла 1.97 мин
# 9700/9798 Длина файла 2.65 мин
# 9701/9798 Длина файла 4.67 мин
# 9702/9798 Длина файла 4.88 мин
# 9703/9798 Длина файла 2.47 мин
# 9704/9798 Длина файла 1.42 мин
# 9705/9798 Длина файла 3.65 мин
# 9706/9798 Длина файла 4.55 мин
# 9707/9798 Длина файла 5.56 мин
# 9708/9798 Длина файла 2.12 мин
# 9709/9798 Длина файла 3.27 мин
# 9710/9798 Длина файла 4.32 мин
# 9711/9798 Длина файла 5.94 мин
# 9712/9798 Длина файла 2.38 мин
# 9713/9798 Длина файла 5.27 мин
# 9714/9798 Длина файла 3.47 мин
# 9715/9798 Длина файла 4.38 мин
# 9716/9798 Длина файла 5.27 мин
# 9717/9798 Длина файла 5.10 мин
# 9718/9798 Длина файла 2.55 мин
# 9719/9798 Длина файла 4.03 мин
# 9720/9798 Длина файла 5.20 мин
# 9721/9798 Длина файла 5.15 мин
# 9722/9798 Длина файла 2.00 мин
# 9723/9798 Длина файла 4.38 мин
# 9724/9798 Длина файла 5.76 мин
# 9725/9798 Длина файла 4.28 мин
# 9726/9798 Длина файла 4.17 мин
# 9727/9798 Длина файла 6.18 мин
# 9728/9798 Длина файла 3.81 мин
# 9729/9798 Длина файла 2.12 мин
# 9730/9798 Длина файла 3.73 мин
# 9731/9798 Длина файла 5.85 мин
# 9732/9798 Длина файла 4.40 мин
# 9733/9798 Длина файла 2.58 мин
# 9734/9798 Длина файла 4.88 мин
# 9735/9798 Длина файла 5.46 мин
# 9736/9798 Длина файла 4.21 мин
# 9737/9798 Длина файла 1.87 мин
# 9738/9798 Длина файла 2.63 мин
# 9739/9798 Длина файла 4.38 мин
# 9740/9798 Длина файла 5.90 мин
# 9741/9798 Длина файла 2.60 мин
# 9742/9798 Длина файла 3.75 мин
# 9743/9798 Длина файла 5.55 мин
# 9744/9798 Длина файла 1.72 мин
# 9745/9798 Длина файла 2.87 мин
# 9746/9798 Длина файла 5.03 мин
# 9747/9798 Длина файла 5.25 мин
# 9748/9798 Длина файла 2.75 мин
# 9749/9798 Длина файла 5.32 мин
# 9750/9798 Длина файла 4.94 мин
# 9751/9798 Длина файла 0.49 мин
# 9752/9798 Длина файла 2.55 мин
# 9753/9798 Длина файла 3.50 мин
# 9754/9798 Длина файла 6.63 мин
# 9755/9798 Длина файла 3.70 мин
# 9756/9798 Длина файла 2.22 мин
# 9757/9798 Длина файла 3.57 мин
# 9758/9798 Длина файла 4.73 мин
# 9759/9798 Длина файла 5.52 мин
# 9760/9798 Длина файла 2.98 мин
# 9761/9798 Длина файла 4.27 мин
# 9762/9798 Длина файла 6.03 мин
# 9763/9798 Длина файла 4.39 мин
# 9764/9798 Длина файла 1.53 мин
# 9765/9798 Длина файла 2.55 мин
# 9766/9798 Длина файла 4.00 мин
# 9767/9798 Длина файла 6.32 мин
# 9768/9798 Длина файла 2.12 мин
# 9769/9798 Длина файла 3.27 мин
# 9770/9798 Длина файла 5.13 мин
# 9771/9798 Длина файла 5.18 мин
# 9772/9798 Длина файла 1.82 мин
# 9773/9798 Длина файла 3.92 мин
# 9774/9798 Длина файла 5.75 мин
# 9775/9798 Длина файла 4.53 мин
# 9776/9798 Длина файла 1.58 мин
# 9777/9798 Длина файла 4.58 мин
# 9778/9798 Длина файла 4.41 мин
# 9779/9798 Длина файла 2.98 мин
# 9780/9798 Длина файла 2.03 мин
# 9781/9798 Длина файла 5.17 мин
# 9782/9798 Длина файла 3.94 мин
# 9783/9798 Длина файла 2.02 мин
# 9784/9798 Длина файла 2.43 мин
# 9785/9798 Длина файла 4.60 мин
# 9786/9798 Длина файла 4.30 мин
# 9787/9798 Длина файла 2.71 мин
# 9788/9798 Длина файла 1.25 мин
# 9789/9798 Длина файла 2.55 мин
# 9790/9798 Длина файла 3.35 мин
# 9791/9798 Длина файла 6.92 мин
# 9792/9798 Длина файла 1.87 мин
# 9793/9798 Длина файла 3.72 мин
# 9794/9798 Длина файла 4.85 мин
# 9795/9798 Длина файла 5.57 мин
# 9796/9798 Длина файла 2.95 мин
# 9797/9798 Длина файла 4.68 мин
# 9798/9798 Длина файла 5.80 мин
# 2. Анализ речи и создание признаков...
# Очистка текста
# Фильтрация пустых ответов
# Анализ речи
# Создание признаков речи ['Качество_речи', 'Лексическое_разнообразие', 'Словарный_запас', 'noun_ratio', 'verb_ratio', 'adjective_ratio', 'NOUN', 'VERB', 'ADJF']
# Создание дополнительных признаков
# 3. Обработка завершена!
# Размер обработанного датасета: (9798, 31)
# Новые колонки: ['Длина_файла', 'Качество_речи', 'Лексическое_разнообразие', 'Словарный_запас', 'noun_ratio', 'verb_ratio', 'adjective_ratio', 'NOUN', 'VERB', 'ADJF', 'question_overlap_ratio', 'Рассуждение', 'Длина_ответа', 'length_ratio', 'length_factor', 'Скорость_речи', 'Уникальных_слов', 'Свобода_речи', 'quality_score', 'quality_vocab_interaction', 'length_speed_interaction', 'noun_adjf_interaction', 'diversity_unique_interaction']

# %% [markdown]
# # **Перезапускаться отсюда**

# %%
df_research.sample(1)
# Out:
#       Id экзамена  Id вопроса  № вопроса                                                                                                                                                                                                                                                                                                                                                                   Текст вопроса Картинка из вопроса  Оценка экзаменатора                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Транскрибация ответа                                                                   Ссылка на оригинальный файл запис  Длина_файла  Качество_речи  ...  length_ratio  length_factor  Скорость_речи  Уникальных_слов  Свобода_речи  quality_score  quality_vocab_interaction  length_speed_interaction  noun_adjf_interaction  diversity_unique_interaction
# 3381      3398291    31074201          3  Вопрос устной части экзамена. Начните диалог. Получите нужную Вам информацию. Будьте вежливы. Представьте ситуацию. Вы пришли в кассы железнодорожного вокзала. Вам нужно купить билеты на поезд до Ташкента. Поздоровайтесь. Узнайте у кассира о наличии билетов, их стоимости. Спросите о скидке для детей. Поблагодарите за полученную информацию и оцените работу кассира.                 NaN                    1  Хорошо. Следующая ситуация. Вам нужно начать диалог, получить нужную информацию и быть вежливым. Ситуация. Вы пришли в кассу железнодорожного вокзала. Вам нужно купить билеты на поезд до Ташкента. Поздоровайтесь. Узнайте у кассира о наличии билетов, их стоимости. Спросите о скидке для детей. Поблагодарите за полученную информацию и оцените работу кассира. Здравствуйте. Здравствуйте. Подскажите, пожалуйста, меня интересуют билеты до Ташкента. На какое число? На 27 число. На 27, к сожалению, нет. Есть на 28. Ну, хорошо. И какая стоимость на 28? 7 тысяч. Взрослый билет. Есть какие-то скидки для детей? Сколько лет вашим детям? Детям 7 и 10. На них уже распространяется скидка до 12 лет. 50%. Отлично. Спасибо большое за информацию. Хорошо. Пойдемте.  https://storage.yandexcloud.net/odin-exam-files-dataset/38e3f17f-3c1a-4d5c-826f-e11b11591bc4-2.MP3       339.31         -18.77  ...          0.56             -1           2.22               92          0.12           5.33                     746.03                   3342.11                    630                        112.98
#
# [1 rows x 31 columns]

# %% [markdown]
# надо вывести фик матрикс и посмотреть важные признаки

# %%
# распределим колонки по типам переменных
numeric_features = [
    'ADJF', # 0.58
    'NOUN', # 0.54
    'Уникальных_слов',    #  0.53
    'Словарный_запас', # 0.52
    'Длина_ответа',  # 0.52
    'length_ratio',  # 0.52
    'quality_vocab_interaction', # 0.51
    'diversity_unique_interaction', # 0.51
    'Лексическое_разнообразие', # 0.50
    'length_speed_interaction', # 0.49
    'VERB',  # 0.49
    'quality_score',  # 0.48 
    'noun_adjf_interaction', # 0.47
    'Скорость_речи',   # 0.46
    'Качество_речи',  # 0.45
    'Длина_файла', # 0.40
       ]

categorical_features = ['№ вопроса'] # 0.52

text_features = [
    'Текст вопроса',  # 0.75
    'Транскрибация ответа' # 0.00
    ]

# %%
# Группировка по целевому признаку и вычисление средних
grouped_means = df_research.groupby('Оценка экзаменатора')[numeric_features].mean()
print(grouped_means)
# Out:
#                      ADJF  NOUN  Уникальных_слов  Словарный_запас  Длина_ответа  length_ratio  quality_vocab_interaction  diversity_unique_interaction  Лексическое_разнообразие  length_speed_interaction  VERB  quality_score  noun_adjf_interaction  Скорость_речи  Качество_речи  Длина_файла
# Оценка экзаменатора
# 0                   10.03 28.63            93.13            71.36        815.24          0.61                    1570.53                        108.20                      0.63                   8645.79 17.23           9.58                 889.70           4.39         -17.32       200.39
# 1                   15.30 39.53           125.90            93.34       1108.83          0.83                    2441.28                        138.50                      0.60                  14299.62 22.43          10.79                2006.89           5.05         -15.49       220.79
# 2                   31.23 71.33           212.84           149.64       1938.70          1.45                    5297.37                        206.32                      0.51                  33733.63 39.17          15.68                5421.41           7.48          -7.69       254.97

# %%
#пайплайн для масштабирования и кодировки с использованием ColumnTransformer


preprocessor = ColumnTransformer(
    transformers=[
        ('num', Pipeline([
            ('imputer', SimpleImputer(strategy='median')),
            ('scaler', StandardScaler())
        ]), numeric_features),
    
        
        ('text_question', TfidfVectorizer(max_features=1500), 'Текст вопроса'),
        ('text_answer', TfidfVectorizer(max_features=1500), 'Транскрибация ответа'),
        
        ('cat', OneHotEncoder(drop='first', handle_unknown='ignore'), categorical_features)
    ],
    remainder='drop'
)

preprocessor
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  ['ADJF', 'NOUN', 'Уникальных_слов',
#                                   'Словарный_запас', 'Длина_ответа',
#                                   'length_ratio', 'quality_vocab_interaction',
#                                   'diversity_unique_interaction',
#                                   'Лексическое_разнообразие',
#                                   'length_speed_interaction', 'VERB',
#                                   'quality_score', 'noun_adjf_interaction',
#                                   'Скорость_речи', 'Качество_речи',
#                                   'Длина_файла']),
#                                 ('text_question',
#                                  TfidfVectorizer(max_features=1500),
#                                  'Текст вопроса'),
#                                 ('text_answer',
#                                  TfidfVectorizer(max_features=1500),
#                                  'Транскрибация ответа'),
#                                 ('cat',
#                                  OneHotEncoder(drop='first',
#                                                handle_unknown='ignore'),
#                                  ['№ вопроса'])])

# %%
preprocessing_pipeline = Pipeline([
    # ('audio_processor', AudioProcessor()),
    # ('data_prep', DataPreprocessor()),
    ('preprocessor', preprocessor)
])

# %%
X = df_research.drop(['Оценка экзаменатора'], axis=1)
y = df_research['Оценка экзаменатора']


# Теперь X_processed - это numpy array/sparse matrix
X_processed = preprocessing_pipeline.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(
    X_processed, y, test_size=0.2, random_state=42, stratify=y
)

# %% [markdown]
# разделить датасет на выборки

# %% [markdown]
# теперь надо создать пайплайн категорировать и масштабировать признаки

# %%
# Создаем полный Pipeline
ModelPipeline = Pipeline([  # Обрабатывает все остальное
    ('selector', SelectKBest(f_classif, k=1500)), # 400 = 239, 779, 761
    ('scaler', StandardScaler()), 
    ('classifier', RandomForestClassifier())
])

ModelPipeline
# Out:
# Pipeline(steps=[('selector', SelectKBest(k=1500)), ('scaler', StandardScaler()),
#                 ('classifier', RandomForestClassifier())])

# %% [markdown]
# создать сетку грид search и сделать кросс-валидацию

# %%
RANDOM_STATE=42

scalers = [StandardScaler(with_mean=False), MaxAbsScaler()]

# Обновленная сетка параметров для Pipeline
models_grid = {
    'LogisticRegression': {
        'ModelPipeline': ModelPipeline,
        'params': {
            'scaler': scalers,
            'classifier': [LogisticRegression(
                # class_weight='balanced',  # с балансировкой только хуже
                random_state=RANDOM_STATE, 
                max_iter=1000)],
            'classifier__C': [0.1, 0.3, 0.5, 1, 1.5],
            'classifier__solver': ['liblinear'],
            'classifier__penalty': ['l2'],
            'classifier__max_iter': [20, 25, 28, 30, 32]
        }
    },
    
    # 'GradientBoosting': {
    #     'ModelPipeline': ModelPipeline,
    #     'params': {
    #         'scaler': scalers,
    #         'classifier': [GradientBoostingClassifier(random_state=RANDOM_STATE)],
    #         'classifier__n_estimators': [60, 61, 62, 63, 65],
    #         'classifier__learning_rate': [0.03, 0.05, 0.07, 0.1],
    #         'classifier__max_depth': [1, 2, 3, 4, 5]
    #     }
    # }
}

# %%
# GridSearchCV с Pipeline
best_models = {}
model_scores = {}

for name, model in models_grid.items():
    grid_search = GridSearchCV(
        model['ModelPipeline'], 
        model['params'],
        cv=StratifiedKFold(n_splits=5, shuffle=True, random_state=42), 
        scoring='neg_mean_absolute_error',
        n_jobs=-1
    )

    grid_search.fit(X_train, y_train)
    y_pred = grid_search.predict(X_test)
    
    best_models[name] = grid_search.best_estimator_
    accuracy = accuracy_score(y_test, y_pred)
    model_scores[name] = accuracy
    mae_test = mean_absolute_error(y_test, y_pred)
    
    print(f"{name}:")
    print(f"train best_score {grid_search.best_score_:.3f}")
    print(f"test (MAE): {mae_test:.3f}")
    print(f"test (accuracy): {accuracy:.3f}")
    print(f"f1_score: {f1_score(y_test, y_pred, average='weighted')}")
    print(f"Лучшие параметры: {grid_search.best_params_}")
    print()
# Out:
# LogisticRegression:
# train best_score -0.221
# test (MAE): 0.223
# test (accuracy): 0.785
# f1_score: 0.7625404207199133
# Лучшие параметры: {'classifier': LogisticRegression(max_iter=1000, random_state=42), 'classifier__C': 0.3, 'classifier__max_iter': 20, 'classifier__penalty': 'l2', 'classifier__solver': 'liblinear', 'scaler': MaxAbsScaler()}

# %%
# После выбора лучшей модели
best_model_name = max(model_scores, key=model_scores.get)
final_best_model = best_models[best_model_name]

# %%
final_best_model
# Out:
# Pipeline(steps=[('selector', SelectKBest(k=1500)), ('scaler', MaxAbsScaler()),
#                 ('classifier',
#                  LogisticRegression(C=0.3, max_iter=20, random_state=42,
#                                     solver='liblinear'))])

# %%
# Найти лучшую модель по метрике
best_model_name = max(model_scores, key=model_scores.get)
best_model = best_models[best_model_name]

# Сохранить модель
import pickle
with open('evaluate_exam_model.pkl', 'wb') as f:
    pickle.dump(best_model, f)
